# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import set_matplotlib_formats
import nltk
from nltk.stem import *
from nltk.tag import *
from nltk import *
from nltk.tokenize import *
# %pylab inline

pd.set_option('display.max_columns', 999)
pd.set_option('display.column_space', 50)

set_matplotlib_formats('retina')
plt.style.use('ggplot')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/Haebichan/anaconda3/lib/python3.6/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['choose', 'find', 'text', 'entropy', 'draw', 'Text', 'flatten', 'stem', 'load']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
df = pd.read_table('train.tsv')

# %%
train = df.copy()

# %%
test = pd.read_table('test.tsv')

# %%
# df = df.iloc[:,2:]

# %%
df.columns = df.columns.str.lower()

# %%
df.phrase[0]
# Out:
# 'A series of escapades demonstrating the adage that what is good for the goose is also good for the gander , some of which occasionally amuses but none of which amounts to much of a story .'

# %%
print(df.sentiment.isnull().sum())
print(df.phrase.isnull().sum())
# Out:
# 0
# 0

# %%
hist(df.sentiment, bins = 5, alpha = 0.5);
xticks(range(5));
xlabel('sentiment', fontsize = 15);

#sentiment histogram showing a normal distribution of the user ratings

# %%
len(df)
# Out:
# 156060

# %%
df['review_word_length'] = df.phrase.apply(lambda x: len(word_tokenize(x)))

# %%
figure = figsize(15,7)
hist(df.review_word_length, bins = 50, color = 'navy', alpha = 0.5)
xticks(range(51));
xlabel('word length of movie reviews');

# %%
figure = figsize(6,6);
hist(df[df.review_word_length == 1].sentiment, bins = 5, alpha = 0.6);
xticks(range(5));
xlabel('count of reviews that only have one word');

# %%
df[df.review_word_length == 3].head(7)
# Out:
#     phraseid  sentenceid                          phrase  sentiment  \
# 10        11           1         demonstrating the adage          2
# 23        24           1                   for the goose          2
# 34        35           1                    the gander ,          2
# 39        40           1                   some of which          2
# 59        60           1                      of a story          2
# 70        71           2  introspective and entertaining          3
# 77        78           2                is worth seeking          4
#
#     review_word_length
# 10                   3
# 23                   3
# 34                   3
# 39                   3
# 59                   3
# 70                   3
# 77                   3

# %%
df.loc[10]
# Out:
# phraseid                                   11
# sentenceid                                  1
# phrase                demonstrating the adage
# sentiment                                   2
# review_word_length                          3
# Name: 10, dtype: object

# %%
df[df.review_word_length == 4].head(7)
# Out:
#      phraseid  sentenceid                            phrase  sentiment  \
# 21         22           1                good for the goose          3
# 57         58           1                   much of a story          2
# 69         70           2  , introspective and entertaining          3
# 76         77           2                is worth seeking .          3
# 87         88           3           Ismail Merchant 's work          2
# 95         96           3                     , I suspect ,          2
# 110       111           3          sitting through this one          1
#
#      review_word_length
# 21                    4
# 57                    4
# 69                    4
# 76                    4
# 87                    4
# 95                    4
# 110                   4

# %%
# can start to see weird repetition in the phrases 

for i in range(10):
    print(df[df.review_word_length == i].head(5))
    print('__________________________________________________________________________')
# Out:
#       phraseid  sentenceid phrase  sentiment  review_word_length
# 2005      2006          76                 1                   0
# __________________________________________________________________________
#     phraseid  sentenceid         phrase  sentiment  review_word_length
# 3          4           1              A          2                   1
# 4          5           1         series          2                   1
# 6          7           1             of          2                   1
# 8          9           1      escapades          2                   1
# 11        12           1  demonstrating          2                   1
# __________________________________________________________________________
#     phraseid  sentenceid      phrase  sentiment  review_word_length
# 2          3           1    A series          2                   2
# 12        13           1   the adage          2                   2
# 25        26           1   the goose          2                   2
# 29        30           1     is also          2                   2
# 35        36           1  the gander          2                   2
# __________________________________________________________________________
#     phraseid  sentenceid                   phrase  sentiment  \
# 10        11           1  demonstrating the adage          2
# 23        24           1            for the goose          2
# 34        35           1             the gander ,          2
# 39        40           1            some of which          2
# 59        60           1               of a story          2
#
#     review_word_length
# 10                   3
# 23                   3
# 34                   3
# 39                   3
# 59                   3
# __________________________________________________________________________
#     phraseid  sentenceid                            phrase  sentiment  \
# 21        22           1                good for the goose          3
# 57        58           1                   much of a story          2
# 69        70           2  , introspective and entertaining          3
# 76        77           2                is worth seeking .          3
# 87        88           3           Ismail Merchant 's work          2
#
#     review_word_length
# 21                   4
# 57                   4
# 69                   4
# 76                   4
# 87                   4
# __________________________________________________________________________
#      phraseid  sentenceid                                  phrase  sentiment  \
# 19         20           1                   is good for the goose          2
# 55         56           1                      to much of a story          2
# 67         68           2  quiet , introspective and entertaining          3
# 86         87           3              of Ismail Merchant 's work          2
# 135       136           4            betrayal , deceit and murder          1
#
#      review_word_length
# 19                    5
# 55                    5
# 67                    5
# 86                    5
# 135                   5
# __________________________________________________________________________
#      phraseid  sentenceid                                             phrase  \
# 17         18           1                         what is good for the goose
# 53         54           1                         amounts to much of a story
# 66         67           2  quiet , introspective and entertaining indepen...
# 134       135           4                     , betrayal , deceit and murder
# 157       158           5  Aggressive self-glorification and a manipulati...
#
#      sentiment  review_word_length
# 17           2                   6
# 53           2                   6
# 66           4                   6
# 134          2                   6
# 157          0                   6
# __________________________________________________________________________
#      phraseid  sentenceid                                             phrase  \
# 15         16           1                    that what is good for the goose
# 52         53           1                   which amounts to much of a story
# 64         65           2  This quiet , introspective and entertaining in...
# 82         83           3               Even fans of Ismail Merchant 's work
# 105       106           3               a hard time sitting through this one
#
#      sentiment  review_word_length
# 15           2                   7
# 52           2                   7
# 64           3                   7
# 82           2                   7
# 105          1                   7
# __________________________________________________________________________
#      phraseid  sentenceid                                         phrase  \
# 51         52           1            of which amounts to much of a story
# 103       104           3      have a hard time sitting through this one
# 131       132           4    the intrigue , betrayal , deceit and murder
# 143       144           4  a Shakespearean tragedy or a juicy soap opera
# 201       202           7         Trouble Every Day is a plodding mess .
#
#      sentiment  review_word_length
# 51           2                   8
# 103          0                   8
# 131          1                   8
# 143          2                   8
# 201          0                   8
# __________________________________________________________________________
#      phraseid  sentenceid                                            phrase  \
# 49         50           1          none of which amounts to much of a story
# 101       102           3   would have a hard time sitting through this one
# 129       130           4   all the intrigue , betrayal , deceit and murder
# 142       143           4  of a Shakespearean tragedy or a juicy soap opera
# 200       201           7          , Trouble Every Day is a plodding mess .
#
#      sentiment  review_word_length
# 49           1                   9
# 101          0                   9
# 129          2                   9
# 142          2                   9
# 200          1                   9
# __________________________________________________________________________

# %% [markdown]
# # ! Replication of the first unique movie review happening for every unique movie review

# %%
[(i,j) for i,j in enumerate(df.phrase)]
# Out:
# [(0,
#   'A series of escapades demonstrating the adage that what is good for the goose is also good for the gander , some of which occasionally amuses but none of which amounts to much of a story .'),
#  (1,
#   'A series of escapades demonstrating the adage that what is good for the goose'),
#  (2, 'A series'),
#  (3, 'A'),
#  (4, 'series'),
#  (5, 'of escapades demonstrating the adage that what is good for the goose'),
#  (6, 'of'),
#  (7, 'escapades demonstrating the adage that what is good for the goose'),
#  (8, 'escapades'),
#  (9, 'demonstrating the adage that what is good for the goose'),
#  (10, 'demonstrating the adage'),
#  (11, 'demonstrating'),
#  (12, 'the adage'),
#  (13, 'the'),
#  (14, 'adage'),
#  (15, 'that what is good for the goose'),
#  (16, 'that'),
#  (17, 'what is good for the goose'),
#  (18, 'what'),
#  (19, 'is good for the goose'),
#  (20, 'is'),
#  (21, 'good for the goose'),
#  (22, 'good'),
#  (23, 'for the goose'),
#  (24, 'for'),
#  (25, 'the goose'),
#  (26, 'goose'),
#  (27,
#   'is also good for the gander , some of which occasionally amuses but none of which amounts to much of a story .'),
#  (28,
#   'is also good for the gander , some of which occasionally amuses but none of which amounts to much of a story'),
#  (29, 'is also'),
#  (30, 'also'),
#  (31,
#   'good for the gander , some of which occasionally amuses but none of which amounts to much of a story'),
#  (32,
#   'for the gander , some of which occasionally amuses but none of which amounts to much of a story'),
#  (33,
#   'the gander , some of which occasionally amuses but none of which amounts to much of a story'),
#  (34, 'the gander ,'),
#  (35, 'the gander'),
#  (36, 'gander'),
#  (37, ','),
#  (38,
#   'some of which occasionally amuses but none of which amounts to much of a story'),
#  (39, 'some of which'),
#  (40, 'some'),
#  (41, 'of which'),
#  (42, 'which'),
#  (43, 'occasionally amuses but none of which amounts to much of a story'),
#  (44, 'occasionally'),
#  (45, 'amuses but none of which amounts to much of a story'),
#  (46, 'amuses'),
#  (47, 'but none of which amounts to much of a story'),
#  (48, 'but'),
#  (49, 'none of which amounts to much of a story'),
#  (50, 'none'),
#  (51, 'of which amounts to much of a story'),
#  (52, 'which amounts to much of a story'),
#  (53, 'amounts to much of a story'),
#  (54, 'amounts'),
#  (55, 'to much of a story'),
#  (56, 'to'),
#  (57, 'much of a story'),
#  (58, 'much'),
#  (59, 'of a story'),
#  (60, 'a story'),
#  (61, 'story'),
#  (62, '.'),
#  (63,
#   'This quiet , introspective and entertaining independent is worth seeking .'),
#  (64, 'This quiet , introspective and entertaining independent'),
#  (65, 'This'),
#  (66, 'quiet , introspective and entertaining independent'),
#  (67, 'quiet , introspective and entertaining'),
#  (68, 'quiet'),
#  (69, ', introspective and entertaining'),
#  (70, 'introspective and entertaining'),
#  (71, 'introspective and'),
#  (72, 'introspective'),
#  (73, 'and'),
#  (74, 'entertaining'),
#  (75, 'independent'),
#  (76, 'is worth seeking .'),
#  (77, 'is worth seeking'),
#  (78, 'is worth'),
#  (79, 'worth'),
#  (80, 'seeking'),
#  (81,
#   "Even fans of Ismail Merchant 's work , I suspect , would have a hard time sitting through this one ."),
#  (82, "Even fans of Ismail Merchant 's work"),
#  (83, 'Even fans'),
#  (84, 'Even'),
#  (85, 'fans'),
#  (86, "of Ismail Merchant 's work"),
#  (87, "Ismail Merchant 's work"),
#  (88, "Ismail Merchant 's"),
#  (89, 'Ismail'),
#  (90, "Merchant 's"),
#  (91, 'Merchant'),
#  (92, "'s"),
#  (93, 'work'),
#  (94, ', I suspect , would have a hard time sitting through this one .'),
#  (95, ', I suspect ,'),
#  (96, 'I suspect ,'),
#  (97, 'I suspect'),
#  (98, 'I'),
#  (99, 'suspect'),
#  (100, 'would have a hard time sitting through this one .'),
#  (101, 'would have a hard time sitting through this one'),
#  (102, 'would'),
#  (103, 'have a hard time sitting through this one'),
#  (104, 'have'),
#  (105, 'a hard time sitting through this one'),
#  (106, 'a hard time'),
#  (107, 'hard time'),
#  (108, 'hard'),
#  (109, 'time'),
#  (110, 'sitting through this one'),
#  (111, 'sitting'),
#  (112, 'through this one'),
#  (113, 'through'),
#  (114, 'this one'),
#  (115, 'one'),
#  (116,
#   'A positively thrilling combination of ethnography and all the intrigue , betrayal , deceit and murder of a Shakespearean tragedy or a juicy soap opera .'),
#  (117,
#   'A positively thrilling combination of ethnography and all the intrigue , betrayal , deceit and murder of a Shakespearean tragedy or a juicy soap opera'),
#  (118,
#   'A positively thrilling combination of ethnography and all the intrigue , betrayal , deceit and murder'),
#  (119, 'A positively thrilling combination'),
#  (120, 'positively thrilling combination'),
#  (121, 'positively'),
#  (122, 'thrilling combination'),
#  (123, 'thrilling'),
#  (124, 'combination'),
#  (125, 'of ethnography and all the intrigue , betrayal , deceit and murder'),
#  (126, 'ethnography and all the intrigue , betrayal , deceit and murder'),
#  (127, 'ethnography and'),
#  (128, 'ethnography'),
#  (129, 'all the intrigue , betrayal , deceit and murder'),
#  (130, 'all'),
#  (131, 'the intrigue , betrayal , deceit and murder'),
#  (132, 'intrigue , betrayal , deceit and murder'),
#  (133, 'intrigue'),
#  (134, ', betrayal , deceit and murder'),
#  (135, 'betrayal , deceit and murder'),
#  (136, 'betrayal'),
#  (137, ', deceit and murder'),
#  (138, 'deceit and murder'),
#  (139, 'deceit and'),
#  (140, 'deceit'),
#  (141, 'murder'),
#  (142, 'of a Shakespearean tragedy or a juicy soap opera'),
#  (143, 'a Shakespearean tragedy or a juicy soap opera'),
#  (144, 'a Shakespearean tragedy or'),
#  (145, 'a Shakespearean tragedy'),
#  (146, 'Shakespearean tragedy'),
#  (147, 'Shakespearean'),
#  (148, 'tragedy'),
#  (149, 'or'),
#  (150, 'a juicy soap opera'),
#  (151, 'juicy soap opera'),
#  (152, 'juicy'),
#  (153, 'soap opera'),
#  (154, 'soap'),
#  (155, 'opera'),
#  (156, 'Aggressive self-glorification and a manipulative whitewash .'),
#  (157, 'Aggressive self-glorification and a manipulative whitewash'),
#  (158, 'Aggressive'),
#  (159, 'self-glorification and a manipulative whitewash'),
#  (160, 'self-glorification and'),
#  (161, 'self-glorification'),
#  (162, 'a manipulative whitewash'),
#  (163, 'manipulative whitewash'),
#  (164, 'manipulative'),
#  (165, 'whitewash'),
#  (166,
#   'A comedy-drama of nearly epic proportions rooted in a sincere performance by the title character undergoing midlife crisis .'),
#  (167, 'A comedy-drama of nearly epic proportions'),
#  (168, 'A comedy-drama'),
#  (169, 'comedy-drama'),
#  (170, 'of nearly epic proportions'),
#  (171, 'nearly epic proportions'),
#  (172, 'nearly epic'),
#  (173, 'nearly'),
#  (174, 'epic'),
#  (175, 'proportions'),
#  (176,
#   'rooted in a sincere performance by the title character undergoing midlife crisis .'),
#  (177,
#   'rooted in a sincere performance by the title character undergoing midlife crisis'),
#  (178, 'rooted in a sincere performance'),
#  (179, 'rooted'),
#  (180, 'in a sincere performance'),
#  (181, 'in'),
#  (182, 'a sincere performance'),
#  (183, 'sincere performance'),
#  (184, 'sincere'),
#  (185, 'performance'),
#  (186, 'by the title character undergoing midlife crisis'),
#  (187, 'by'),
#  (188, 'the title character undergoing midlife crisis'),
#  (189, 'the title character'),
#  (190, 'title character'),
#  (191, 'title'),
#  (192, 'character'),
#  (193, 'undergoing midlife crisis'),
#  (194, 'undergoing'),
#  (195, 'midlife crisis'),
#  (196, 'midlife'),
#  (197, 'crisis'),
#  (198, 'Narratively , Trouble Every Day is a plodding mess .'),
#  (199, 'Narratively'),
#  (200, ', Trouble Every Day is a plodding mess .'),
#  (201, 'Trouble Every Day is a plodding mess .'),
#  (202, 'Trouble Every Day'),
#  (203, 'Trouble'),
#  (204, 'Every Day'),
#  (205, 'Every'),
#  (206, 'Day'),
#  (207, 'is a plodding mess .'),
#  (208, 'is a plodding mess'),
#  (209, 'a plodding mess'),
#  (210, 'plodding mess'),
#  (211, 'plodding'),
#  (212, 'mess'),
#  (213,
#   "The Importance of Being Earnest , so thick with wit it plays like a reading from Bartlett 's Familiar Quotations"),
#  (214, 'The Importance'),
#  (215, 'Importance'),
#  (216,
#   "of Being Earnest , so thick with wit it plays like a reading from Bartlett 's Familiar Quotations"),
#  (217,
#   "Being Earnest , so thick with wit it plays like a reading from Bartlett 's Familiar Quotations"),
#  (218, 'Being'),
#  (219,
#   "Earnest , so thick with wit it plays like a reading from Bartlett 's Familiar Quotations"),
#  (220, 'Earnest ,'),
#  (221, 'Earnest'),
#  (222,
#   "so thick with wit it plays like a reading from Bartlett 's Familiar Quotations"),
#  (223, 'so'),
#  (224,
#   "thick with wit it plays like a reading from Bartlett 's Familiar Quotations"),
#  (225, 'thick'),
#  (226,
#   "with wit it plays like a reading from Bartlett 's Familiar Quotations"),
#  (227, 'with'),
#  (228, "wit it plays like a reading from Bartlett 's Familiar Quotations"),
#  (229, 'wit'),
#  (230, "it plays like a reading from Bartlett 's Familiar Quotations"),
#  (231, 'it'),
#  (232, "plays like a reading from Bartlett 's Familiar Quotations"),
#  (233, 'plays'),
#  (234, "like a reading from Bartlett 's Familiar Quotations"),
#  (235, 'like'),
#  (236, "a reading from Bartlett 's Familiar Quotations"),
#  (237, 'a reading'),
#  (238, 'reading'),
#  (239, "from Bartlett 's Familiar Quotations"),
#  (240, 'from'),
#  (241, "Bartlett 's Familiar Quotations"),
#  (242, "Bartlett 's"),
#  (243, 'Bartlett'),
#  (244, 'Familiar Quotations'),
#  (245, 'Familiar'),
#  (246, 'Quotations'),
#  (247, "But it does n't leave you with much ."),
#  (248, "it does n't leave you with much ."),
#  (249, "does n't leave you with much ."),
#  (250, "does n't leave you with much"),
#  (251, "does n't"),
#  (252, 'does'),
#  (253, "n't"),
#  (254, 'leave you with much'),
#  (255, 'leave you'),
#  (256, 'leave'),
#  (257, 'you'),
#  (258, 'with much'),
#  (259, 'You could hate it for the same reason .'),
#  (260, 'could hate it for the same reason .'),
#  (261, 'could hate it for the same reason'),
#  (262, 'could'),
#  (263, 'hate it for the same reason'),
#  (264, 'hate it'),
#  (265, 'hate'),
#  (266, 'for the same reason'),
#  (267, 'the same reason'),
#  (268, 'same reason'),
#  (269, 'same'),
#  (270, 'reason'),
#  (271,
#   "There 's little to recommend Snow Dogs , unless one considers cliched dialogue and perverse escapism a source of high hilarity ."),
#  (272, 'There'),
#  (273,
#   "'s little to recommend Snow Dogs , unless one considers cliched dialogue and perverse escapism a source of high hilarity ."),
#  (274,
#   "'s little to recommend Snow Dogs , unless one considers cliched dialogue and perverse escapism a source of high hilarity"),
#  (275, "'s little to recommend Snow Dogs ,"),
#  (276, "'s little to recommend Snow Dogs"),
#  (277, 'little to recommend Snow Dogs'),
#  (278, 'little'),
#  (279, 'to recommend Snow Dogs'),
#  (280, 'recommend Snow Dogs'),
#  (281, 'recommend'),
#  (282, 'Snow Dogs'),
#  (283, 'Snow'),
#  (284, 'Dogs'),
#  (285,
#   'unless one considers cliched dialogue and perverse escapism a source of high hilarity'),
#  (286, 'unless'),
#  (287,
#   'one considers cliched dialogue and perverse escapism a source of high hilarity'),
#  (288,
#   'considers cliched dialogue and perverse escapism a source of high hilarity'),
#  (289, 'considers'),
#  (290, 'cliched dialogue and perverse escapism a source of high hilarity'),
#  (291, 'cliched dialogue and perverse escapism'),
#  (292, 'cliched dialogue and'),
#  (293, 'cliched dialogue'),
#  (294, 'cliched'),
#  (295, 'dialogue'),
#  (296, 'perverse escapism'),
#  (297, 'perverse'),
#  (298, 'escapism'),
#  (299, 'a source of high hilarity'),
#  (300, 'a source'),
#  (301, 'source'),
#  (302, 'of high hilarity'),
#  (303, 'high hilarity'),
#  (304, 'high'),
#  (305, 'hilarity'),
#  (306,
#   "Kung Pow is Oedekerk 's realization of his childhood dream to be in a martial-arts flick , and proves that sometimes the dreams of youth should remain just that ."),
#  (307, 'Kung Pow'),
#  (308, 'Kung'),
#  (309, 'Pow'),
#  (310,
#   "is Oedekerk 's realization of his childhood dream to be in a martial-arts flick , and proves that sometimes the dreams of youth should remain just that ."),
#  (311,
#   "is Oedekerk 's realization of his childhood dream to be in a martial-arts flick , and proves that sometimes the dreams of youth should remain just that"),
#  (312,
#   "is Oedekerk 's realization of his childhood dream to be in a martial-arts flick , and"),
#  (313,
#   "is Oedekerk 's realization of his childhood dream to be in a martial-arts flick ,"),
#  (314,
#   "is Oedekerk 's realization of his childhood dream to be in a martial-arts flick"),
#  (315,
#   "Oedekerk 's realization of his childhood dream to be in a martial-arts flick"),
#  (316, "Oedekerk 's realization of his childhood dream"),
#  (317, "Oedekerk 's realization"),
#  (318, "Oedekerk 's"),
#  (319, 'Oedekerk'),
#  (320, 'realization'),
#  (321, 'of his childhood dream'),
#  (322, 'his childhood dream'),
#  (323, 'his'),
#  (324, 'childhood dream'),
#  (325, 'childhood'),
#  (326, 'dream'),
#  (327, 'to be in a martial-arts flick'),
#  (328, 'be in a martial-arts flick'),
#  (329, 'be'),
#  (330, 'in a martial-arts flick'),
#  (331, 'a martial-arts flick'),
#  (332, 'martial-arts flick'),
#  (333, 'martial-arts'),
#  (334, 'flick'),
#  (335, 'proves that sometimes the dreams of youth should remain just that'),
#  (336, 'proves'),
#  (337, 'that sometimes the dreams of youth should remain just that'),
#  (338, 'sometimes the dreams of youth should remain just that'),
#  (339, 'sometimes'),
#  (340, 'the dreams of youth should remain just that'),
#  (341, 'the dreams of youth'),
#  (342, 'the dreams'),
#  (343, 'dreams'),
#  (344, 'of youth'),
#  (345, 'youth'),
#  (346, 'should remain just that'),
#  (347, 'should'),
#  (348, 'remain just that'),
#  (349, 'remain'),
#  (350, 'just that'),
#  (351, 'just'),
#  (352, 'The performances are an absolute joy .'),
#  (353, 'The performances'),
#  (354, 'performances'),
#  (355, 'are an absolute joy .'),
#  (356, 'are an absolute joy'),
#  (357, 'are'),
#  (358, 'an absolute joy'),
#  (359, 'an'),
#  (360, 'absolute joy'),
#  (361, 'absolute'),
#  (362, 'joy'),
#  (363,
#   'Fresnadillo has something serious to say about the ways in which extravagant chance can distort our perspective and throw us off the path of good sense .'),
#  (364, 'Fresnadillo'),
#  (365,
#   'has something serious to say about the ways in which extravagant chance can distort our perspective and throw us off the path of good sense .'),
#  (366,
#   'has something serious to say about the ways in which extravagant chance can distort our perspective and throw us off the path of good sense'),
#  (367, 'has'),
#  (368,
#   'something serious to say about the ways in which extravagant chance can distort our perspective and throw us off the path of good sense'),
#  (369, 'something'),
#  (370,
#   'serious to say about the ways in which extravagant chance can distort our perspective and throw us off the path of good sense'),
#  (371, 'serious'),
#  (372,
#   'to say about the ways in which extravagant chance can distort our perspective and throw us off the path of good sense'),
#  (373,
#   'say about the ways in which extravagant chance can distort our perspective and throw us off the path of good sense'),
#  (374, 'say'),
#  (375,
#   'about the ways in which extravagant chance can distort our perspective and throw us off the path of good sense'),
#  (376, 'about'),
#  (377,
#   'the ways in which extravagant chance can distort our perspective and throw us off the path of good sense'),
#  (378, 'the ways'),
#  (379, 'ways'),
#  (380,
#   'in which extravagant chance can distort our perspective and throw us off the path of good sense'),
#  (381, 'in which'),
#  (382,
#   'extravagant chance can distort our perspective and throw us off the path of good sense'),
#  (383, 'extravagant chance'),
#  (384, 'extravagant'),
#  (385, 'chance'),
#  (386, 'can distort our perspective and throw us off the path of good sense'),
#  (387, 'can'),
#  (388, 'distort our perspective and throw us off the path of good sense'),
#  (389, 'distort our perspective and'),
#  (390, 'distort our perspective'),
#  (391, 'distort'),
#  (392, 'our perspective'),
#  (393, 'our'),
#  (394, 'perspective'),
#  (395, 'throw us off the path of good sense'),
#  (396, 'throw us'),
#  (397, 'throw'),
#  (398, 'us'),
#  (399, 'off the path of good sense'),
#  (400, 'off'),
#  (401, 'the path of good sense'),
#  (402, 'the path'),
#  (403, 'path'),
#  (404, 'of good sense'),
#  (405, 'good sense'),
#  (406, 'sense'),
#  (407, 'I still like Moonlight Mile , better judgment be damned .'),
#  (408, 'still like Moonlight Mile , better judgment be damned .'),
#  (409, 'still'),
#  (410, 'like Moonlight Mile , better judgment be damned .'),
#  (411, 'like Moonlight Mile , better judgment be damned'),
#  (412, 'Moonlight Mile , better judgment be damned'),
#  (413, 'Moonlight Mile , better judgment'),
#  (414, 'Moonlight'),
#  (415, 'Mile , better judgment'),
#  (416, 'Mile'),
#  (417, ', better judgment'),
#  (418, 'better judgment'),
#  (419, 'better'),
#  (420, 'judgment'),
#  (421, 'be damned'),
#  (422, 'damned'),
#  (423,
#   'A welcome relief from baseball movies that try too hard to be mythic , this one is a sweet and modest and ultimately winning story .'),
#  (424, 'A welcome relief from baseball movies that try too hard to be mythic'),
#  (425, 'A welcome relief'),
#  (426, 'welcome relief'),
#  (427, 'welcome'),
#  (428, 'relief'),
#  (429, 'from baseball movies that try too hard to be mythic'),
#  (430, 'baseball movies that try too hard to be mythic'),
#  (431, 'baseball movies'),
#  (432, 'baseball'),
#  (433, 'movies'),
#  (434, 'that try too hard to be mythic'),
#  (435, 'try too hard to be mythic'),
#  (436, 'try'),
#  (437, 'too hard to be mythic'),
#  (438, 'too'),
#  (439, 'hard to be mythic'),
#  (440, 'to be mythic'),
#  (441, 'be mythic'),
#  (442, 'mythic'),
#  (443, ', this one is a sweet and modest and ultimately winning story .'),
#  (444, 'this one is a sweet and modest and ultimately winning story .'),
#  (445, 'is a sweet and modest and ultimately winning story .'),
#  (446, 'is a sweet and modest and ultimately winning story'),
#  (447, 'a sweet and modest and ultimately winning story'),
#  (448, 'a sweet and modest and'),
#  (449, 'a sweet and modest'),
#  (450, 'sweet and modest'),
#  (451, 'sweet and'),
#  (452, 'sweet'),
#  (453, 'modest'),
#  (454, 'ultimately winning story'),
#  (455, 'ultimately'),
#  (456, 'winning story'),
#  (457, 'winning'),
#  (458, 'a bilingual charmer , just like the woman who inspired it'),
#  (459, 'a bilingual charmer ,'),
#  (460, 'a bilingual charmer'),
#  (461, 'bilingual charmer'),
#  (462, 'bilingual'),
#  (463, 'charmer'),
#  (464, 'just like the woman who inspired it'),
#  (465, 'like the woman who inspired it'),
#  (466, 'the woman who inspired it'),
#  (467, 'the woman'),
#  (468, 'woman'),
#  (469, 'who inspired it'),
#  (470, 'who'),
#  (471, 'inspired it'),
#  (472, 'inspired'),
#  (473,
#   "Like a less dizzily gorgeous companion to Mr. Wong 's In the Mood for Love -- very much a Hong Kong movie despite its mainland setting ."),
#  (474, 'Like a less dizzily gorgeous companion to Mr.'),
#  (475, 'a less dizzily gorgeous companion to Mr.'),
#  (476, 'a less dizzily gorgeous companion'),
#  (477, 'less dizzily gorgeous companion'),
#  (478, 'less dizzily gorgeous'),
#  (479, 'less'),
#  (480, 'dizzily gorgeous'),
#  (481, 'dizzily'),
#  (482, 'gorgeous'),
#  (483, 'companion'),
#  (484, 'to Mr.'),
#  (485, 'Mr.'),
#  (486,
#   "Wong 's In the Mood for Love -- very much a Hong Kong movie despite its mainland setting ."),
#  (487, 'Wong'),
#  (488,
#   "'s In the Mood for Love -- very much a Hong Kong movie despite its mainland setting ."),
#  (489,
#   "'s In the Mood for Love -- very much a Hong Kong movie despite its mainland setting"),
#  (490, "'s In the Mood for Love -- very much a Hong Kong movie"),
#  (491, 'In the Mood for Love -- very much a Hong Kong movie'),
#  (492, 'the Mood for Love -- very much a Hong Kong movie'),
#  (493, 'the Mood'),
#  (494, 'Mood'),
#  (495, 'for Love -- very much a Hong Kong movie'),
#  (496, 'Love -- very much a Hong Kong movie'),
#  (497, 'Love -- very much'),
#  (498, 'Love --'),
#  (499, 'Love'),
#  (500, '--'),
#  (501, 'very much'),
#  (502, 'very'),
#  (503, 'a Hong Kong movie'),
#  (504, 'Hong Kong movie'),
#  (505, 'Hong'),
#  (506, 'Kong movie'),
#  (507, 'Kong'),
#  (508, 'movie'),
#  (509, 'despite its mainland setting'),
#  (510, 'despite'),
#  (511, 'its mainland setting'),
#  (512, 'its'),
#  (513, 'mainland setting'),
#  (514, 'mainland'),
#  (515, 'setting'),
#  (516,
#   'As inept as big-screen remakes of The Avengers and The Wild Wild West .'),
#  (517,
#   'As inept as big-screen remakes of The Avengers and The Wild Wild West'),
#  (518, 'As inept'),
#  (519, 'As'),
#  (520, 'inept'),
#  (521, 'as big-screen remakes of The Avengers and The Wild Wild West'),
#  (522, 'big-screen remakes of The Avengers and The Wild Wild West'),
#  (523, 'big-screen remakes'),
#  (524, 'big-screen'),
#  (525, 'remakes'),
#  (526, 'of The Avengers and The Wild Wild West'),
#  (527, 'The Avengers and The Wild Wild West'),
#  (528, 'The Avengers and'),
#  (529, 'The Avengers'),
#  (530, 'Avengers'),
#  (531, 'The Wild Wild West'),
#  (532, 'Wild Wild West'),
#  (533, 'Wild'),
#  (534, 'Wild West'),
#  (535, 'West'),
#  (536, "It 's everything you 'd expect -- but nothing more ."),
#  (537, "'s everything you 'd expect -- but nothing more ."),
#  (538, "'s everything you 'd expect -- but nothing more"),
#  (539, "everything you 'd expect -- but nothing more"),
#  (540, 'everything'),
#  (541, "you 'd expect -- but nothing more"),
#  (542, "'d expect -- but nothing more"),
#  (543, "'d"),
#  (544, 'expect -- but nothing more'),
#  (545, 'expect -- but nothing'),
#  (546, 'expect --'),
#  (547, 'expect'),
#  (548, 'but nothing'),
#  (549, 'nothing'),
#  (550, 'more'),
#  (551, 'Best indie of the year , so far .'),
#  (552, 'Best'),
#  (553, 'indie of the year , so far .'),
#  (554, 'indie of the year , so far'),
#  (555, 'indie of the year ,'),
#  (556, 'indie of the year'),
#  (557, 'indie'),
#  (558, 'of the year'),
#  (559, 'the year'),
#  (560, 'year'),
#  (561, 'so far'),
#  (562, 'far'),
#  (563,
#   "Hatfield and Hicks make the oddest of couples , and in this sense the movie becomes a study of the gambles of the publishing world , offering a case study that exists apart from all the movie 's political ramifications ."),
#  (564,
#   "Hatfield and Hicks make the oddest of couples , and in this sense the movie becomes a study of the gambles of the publishing world , offering a case study that exists apart from all the movie 's political ramifications"),
#  (565, 'Hatfield and Hicks make the oddest of couples , and'),
#  (566, 'Hatfield and Hicks make the oddest of couples ,'),
#  (567, 'Hatfield and Hicks make the oddest of couples'),
#  (568, 'Hatfield and Hicks'),
#  (569, 'Hatfield and'),
#  (570, 'Hatfield'),
#  (571, 'Hicks'),
#  (572, 'make the oddest of couples'),
#  (573, 'make'),
#  (574, 'the oddest of couples'),
#  (575, 'the oddest'),
#  (576, 'oddest'),
#  (577, 'of couples'),
#  (578, 'couples'),
#  (579,
#   "in this sense the movie becomes a study of the gambles of the publishing world , offering a case study that exists apart from all the movie 's political ramifications"),
#  (580, 'in this sense'),
#  (581, 'this sense'),
#  (582,
#   "the movie becomes a study of the gambles of the publishing world , offering a case study that exists apart from all the movie 's political ramifications"),
#  (583, 'the movie'),
#  (584,
#   "becomes a study of the gambles of the publishing world , offering a case study that exists apart from all the movie 's political ramifications"),
#  (585, 'becomes a study of the gambles of the publishing world ,'),
#  (586, 'becomes a study of the gambles of the publishing world'),
#  (587, 'becomes'),
#  (588, 'a study of the gambles of the publishing world'),
#  (589, 'a study'),
#  (590, 'study'),
#  (591, 'of the gambles of the publishing world'),
#  (592, 'the gambles of the publishing world'),
#  (593, 'the gambles'),
#  (594, 'gambles'),
#  (595, 'of the publishing world'),
#  (596, 'the publishing world'),
#  (597, 'publishing world'),
#  (598, 'publishing'),
#  (599, 'world'),
#  (600,
#   "offering a case study that exists apart from all the movie 's political ramifications"),
#  (601, 'offering'),
#  (602,
#   "a case study that exists apart from all the movie 's political ramifications"),
#  (603, 'a case study'),
#  (604, 'case study'),
#  (605, 'case'),
#  (606, "that exists apart from all the movie 's political ramifications"),
#  (607, "exists apart from all the movie 's political ramifications"),
#  (608, 'exists apart'),
#  (609, 'exists'),
#  (610, 'apart'),
#  (611, "from all the movie 's political ramifications"),
#  (612, "all the movie 's political ramifications"),
#  (613, "the movie 's political ramifications"),
#  (614, "the movie 's"),
#  (615, "movie 's"),
#  (616, 'political ramifications'),
#  (617, 'political'),
#  (618, 'ramifications'),
#  (619,
#   "It 's like going to a house party and watching the host defend himself against a frothing ex-girlfriend ."),
#  (620,
#   "'s like going to a house party and watching the host defend himself against a frothing ex-girlfriend ."),
#  (621,
#   "'s like going to a house party and watching the host defend himself against a frothing ex-girlfriend"),
#  (622,
#   'like going to a house party and watching the host defend himself against a frothing ex-girlfriend'),
#  (623,
#   'going to a house party and watching the host defend himself against a frothing ex-girlfriend'),
#  (624, 'going to a house party and'),
#  (625, 'going to a house party'),
#  (626, 'going'),
#  (627, 'to a house party'),
#  (628, 'a house party'),
#  (629, 'house party'),
#  (630, 'house'),
#  (631, 'party'),
#  (632, 'watching the host defend himself against a frothing ex-girlfriend'),
#  (633, 'watching'),
#  (634, 'the host defend himself against a frothing ex-girlfriend'),
#  (635, 'the host'),
#  (636, 'host'),
#  (637, 'defend himself against a frothing ex-girlfriend'),
#  (638, 'defend himself'),
#  (639, 'defend'),
#  (640, 'himself'),
#  (641, 'against a frothing ex-girlfriend'),
#  (642, 'against'),
#  (643, 'a frothing ex-girlfriend'),
#  (644, 'frothing ex-girlfriend'),
#  (645, 'frothing'),
#  (646, 'ex-girlfriend'),
#  (647,
#   "That the Chuck Norris `` grenade gag '' occurs about 7 times during Windtalkers is a good indication of how serious-minded the film is ."),
#  (648, "That the Chuck Norris `` grenade gag ''"),
#  (649, "the Chuck Norris `` grenade gag ''"),
#  (650, "Chuck Norris `` grenade gag ''"),
#  (651, 'Chuck'),
#  (652, "Norris `` grenade gag ''"),
#  (653, 'Norris'),
#  (654, "`` grenade gag ''"),
#  (655, '``'),
#  (656, "grenade gag ''"),
#  (657, 'grenade'),
#  (658, "gag ''"),
#  (659, 'gag'),
#  (660, "''"),
#  (661,
#   'occurs about 7 times during Windtalkers is a good indication of how serious-minded the film is .'),
#  (662,
#   'occurs about 7 times during Windtalkers is a good indication of how serious-minded the film is'),
#  (663, 'occurs'),
#  (664,
#   'about 7 times during Windtalkers is a good indication of how serious-minded the film is'),
#  (665, 'about 7 times during Windtalkers'),
#  (666, 'about 7 times'),
#  (667, '7 times'),
#  (668, '7'),
#  (669, 'times'),
#  (670, 'during Windtalkers'),
#  (671, 'during'),
#  (672, 'Windtalkers'),
#  (673, 'is a good indication of how serious-minded the film is'),
#  (674, 'a good indication of how serious-minded the film is'),
#  (675, 'a good indication'),
#  (676, 'good indication'),
#  (677, 'indication'),
#  (678, 'of how serious-minded the film is'),
#  (679, 'how serious-minded the film is'),
#  (680, 'how'),
#  (681, 'serious-minded the film is'),
#  (682, 'serious-minded the film'),
#  (683, 'serious-minded'),
#  (684, 'the film'),
#  (685, 'film'),
#  (686, 'The plot is romantic comedy boilerplate from start to finish .'),
#  (687, 'The plot'),
#  (688, 'plot'),
#  (689, 'is romantic comedy boilerplate from start to finish .'),
#  (690, 'is romantic comedy boilerplate from start to finish'),
#  (691, 'romantic comedy boilerplate from start to finish'),
#  (692, 'romantic comedy boilerplate from start'),
#  (693, 'romantic comedy boilerplate'),
#  (694, 'romantic'),
#  (695, 'comedy boilerplate'),
#  (696, 'comedy'),
#  (697, 'boilerplate'),
#  (698, 'from start'),
#  (699, 'start'),
#  (700, 'to finish'),
#  (701, 'finish'),
#  (702,
#   'It arrives with an impeccable pedigree , mongrel pep , and almost indecipherable plot complications .'),
#  (703,
#   'arrives with an impeccable pedigree , mongrel pep , and almost indecipherable plot complications .'),
#  (704,
#   'arrives with an impeccable pedigree , mongrel pep , and almost indecipherable plot complications'),
#  (705, 'arrives'),
#  (706,
#   'with an impeccable pedigree , mongrel pep , and almost indecipherable plot complications'),
#  (707,
#   'an impeccable pedigree , mongrel pep , and almost indecipherable plot complications'),
#  (708, 'an impeccable pedigree , mongrel pep , and almost'),
#  (709, 'an impeccable pedigree , mongrel pep , and'),
#  (710, 'an impeccable pedigree , mongrel pep ,'),
#  (711, 'an impeccable pedigree , mongrel pep'),
#  (712, 'impeccable pedigree , mongrel pep'),
#  (713, 'impeccable'),
#  (714, 'pedigree , mongrel pep'),
#  (715, 'pedigree'),
#  (716, ', mongrel pep'),
#  (717, 'mongrel pep'),
#  (718, 'mongrel'),
#  (719, 'pep'),
#  (720, 'almost'),
#  (721, 'indecipherable plot complications'),
#  (722, 'indecipherable'),
#  (723, 'plot complications'),
#  (724, 'complications'),
#  (725, 'A film that clearly means to preach exclusively to the converted .'),
#  (726, 'A film that clearly means to'),
#  (727, 'A film'),
#  (728, 'that clearly means to'),
#  (729, 'clearly means to'),
#  (730, 'clearly'),
#  (731, 'means to'),
#  (732, 'means'),
#  (733, 'preach exclusively to the converted .'),
#  (734, 'preach exclusively to the converted'),
#  (735, 'preach exclusively'),
#  (736, 'preach'),
#  (737, 'exclusively'),
#  (738, 'to the converted'),
#  (739, 'the converted'),
#  (740, 'converted'),
#  (741,
#   "While The Importance of Being Earnest offers opportunities for occasional smiles and chuckles , it does n't give us a reason to be in the theater beyond Wilde 's wit and the actors ' performances ."),
#  (742,
#   'While The Importance of Being Earnest offers opportunities for occasional smiles and chuckles'),
#  (743, 'While'),
#  (744,
#   'The Importance of Being Earnest offers opportunities for occasional smiles and chuckles'),
#  (745, 'The Importance of Being Earnest'),
#  (746, 'of Being Earnest'),
#  (747, 'Being Earnest'),
#  (748, 'offers opportunities for occasional smiles and chuckles'),
#  (749, 'offers opportunities for occasional smiles and'),
#  (750, 'offers opportunities for occasional smiles'),
#  (751, 'offers'),
#  (752, 'opportunities for occasional smiles'),
#  (753, 'opportunities'),
#  (754, 'for occasional smiles'),
#  (755, 'occasional smiles'),
#  (756, 'occasional'),
#  (757, 'smiles'),
#  (758, 'chuckles'),
#  (759,
#   ", it does n't give us a reason to be in the theater beyond Wilde 's wit and the actors ' performances ."),
#  (760,
#   "it does n't give us a reason to be in the theater beyond Wilde 's wit and the actors ' performances ."),
#  (761,
#   "does n't give us a reason to be in the theater beyond Wilde 's wit and the actors ' performances ."),
#  (762,
#   "does n't give us a reason to be in the theater beyond Wilde 's wit and the actors ' performances"),
#  (763,
#   "give us a reason to be in the theater beyond Wilde 's wit and the actors ' performances"),
#  (764, 'give us'),
#  (765, 'give'),
#  (766,
#   "a reason to be in the theater beyond Wilde 's wit and the actors ' performances"),
#  (767,
#   "reason to be in the theater beyond Wilde 's wit and the actors ' performances"),
#  (768,
#   "to be in the theater beyond Wilde 's wit and the actors ' performances"),
#  (769, "be in the theater beyond Wilde 's wit and the actors ' performances"),
#  (770, 'be in the theater'),
#  (771, 'in the theater'),
#  (772, 'the theater'),
#  (773, 'theater'),
#  (774, "beyond Wilde 's wit and the actors ' performances"),
#  (775, 'beyond'),
#  (776, "Wilde 's wit and the actors ' performances"),
#  (777, "Wilde 's wit and"),
#  (778, "Wilde 's wit"),
#  (779, "Wilde 's"),
#  (780, 'Wilde'),
#  (781, "the actors ' performances"),
#  (782, "the actors '"),
#  (783, "actors '"),
#  (784, 'actors'),
#  (785, "'"),
#  (786,
#   "The latest vapid actor 's exercise to appropriate the structure of Arthur Schnitzler 's Reigen ."),
#  (787, 'The latest'),
#  (788, 'latest'),
#  (789,
#   "vapid actor 's exercise to appropriate the structure of Arthur Schnitzler 's Reigen ."),
#  (790,
#   "vapid actor 's exercise to appropriate the structure of Arthur Schnitzler 's Reigen"),
#  (791, "vapid actor 's exercise"),
#  (792, 'vapid'),
#  (793, "actor 's exercise"),
#  (794, "actor 's"),
#  (795, 'actor'),
#  (796, 'exercise'),
#  (797, "to appropriate the structure of Arthur Schnitzler 's Reigen"),
#  (798, "appropriate the structure of Arthur Schnitzler 's Reigen"),
#  (799, 'appropriate the structure'),
#  (800, 'appropriate'),
#  (801, 'the structure'),
#  (802, 'structure'),
#  (803, "of Arthur Schnitzler 's Reigen"),
#  (804, "Arthur Schnitzler 's Reigen"),
#  (805, "Arthur Schnitzler 's"),
#  (806, 'Arthur'),
#  (807, "Schnitzler 's"),
#  (808, 'Schnitzler'),
#  (809, 'Reigen'),
#  (810,
#   "More vaudeville show than well-constructed narrative , but on those terms it 's inoffensive and actually rather sweet ."),
#  (811,
#   "More vaudeville show than well-constructed narrative , but on those terms it 's inoffensive and actually rather sweet"),
#  (812, 'More vaudeville show than well-constructed narrative , but'),
#  (813, 'More vaudeville show than well-constructed narrative ,'),
#  (814, 'More vaudeville show than well-constructed narrative'),
#  (815, 'More vaudeville'),
#  (816, 'vaudeville'),
#  (817, 'show than well-constructed narrative'),
#  (818, 'show'),
#  (819, 'than well-constructed narrative'),
#  (820, 'than'),
#  (821, 'well-constructed narrative'),
#  (822, 'well-constructed'),
#  (823, 'narrative'),
#  (824, "on those terms it 's inoffensive and actually rather sweet"),
#  (825, 'on those terms'),
#  (826, 'on'),
#  (827, 'those terms'),
#  (828, 'those'),
#  (829, 'terms'),
#  (830, "it 's inoffensive and actually rather sweet"),
#  (831, "'s inoffensive and actually rather sweet"),
#  (832, 'inoffensive and actually rather sweet'),
#  (833, 'inoffensive and actually'),
#  (834, 'inoffensive and'),
#  (835, 'inoffensive'),
#  (836, 'actually'),
#  (837, 'rather sweet'),
#  (838, 'rather'),
#  (839, 'Nothing more than a run-of-the-mill action flick .'),
#  (840, 'more than a run-of-the-mill action flick .'),
#  (841, 'more than a run-of-the-mill action'),
#  (842, 'than a run-of-the-mill action'),
#  (843, 'a run-of-the-mill action'),
#  (844, 'run-of-the-mill action'),
#  (845, 'run-of-the-mill'),
#  (846, 'action'),
#  (847, 'flick .'),
#  (848,
#   'Hampered -- no , paralyzed -- by a self-indulgent script ... that aims for poetry and ends up sounding like satire .'),
#  (849,
#   'Hampered -- no , paralyzed -- by a self-indulgent script ... that aims for poetry and ends up sounding like satire'),
#  (850, 'Hampered -- no , paralyzed -- by a self-indulgent script ...'),
#  (851, 'Hampered -- no , paralyzed -- by a self-indulgent script'),
#  (852, 'Hampered -- no , paralyzed --'),
#  (853, 'Hampered'),
#  (854, '-- no , paralyzed --'),
#  (855, 'no , paralyzed --'),
#  (856, 'no , paralyzed'),
#  (857, 'no'),
#  (858, ', paralyzed'),
#  (859, 'paralyzed'),
#  (860, 'by a self-indulgent script'),
#  (861, 'a self-indulgent script'),
#  (862, 'self-indulgent script'),
#  (863, 'self-indulgent'),
#  (864, 'script'),
#  (865, '...'),
#  (866, 'that aims for poetry and ends up sounding like satire'),
#  (867, 'aims for poetry and ends up sounding like satire'),
#  (868, 'aims for poetry and'),
#  (869, 'aims for poetry'),
#  (870, 'aims'),
#  (871, 'for poetry'),
#  (872, 'poetry'),
#  (873, 'ends up sounding like satire'),
#  (874, 'ends up'),
#  (875, 'ends'),
#  (876, 'up'),
#  (877, 'sounding like satire'),
#  (878, 'sounding'),
#  (879, 'like satire'),
#  (880, 'satire'),
#  (881,
#   'Ice Age is the first computer-generated feature cartoon to feel like other movies , and that makes for some glacial pacing early on .'),
#  (882,
#   'Ice Age is the first computer-generated feature cartoon to feel like other movies , and that makes for some glacial pacing early on'),
#  (883,
#   'Ice Age is the first computer-generated feature cartoon to feel like other movies , and'),
#  (884,
#   'Ice Age is the first computer-generated feature cartoon to feel like other movies ,'),
#  (885,
#   'Ice Age is the first computer-generated feature cartoon to feel like other movies'),
#  (886, 'Ice Age'),
#  (887, 'Ice'),
#  (888, 'Age'),
#  (889,
#   'is the first computer-generated feature cartoon to feel like other movies'),
#  (890,
#   'the first computer-generated feature cartoon to feel like other movies'),
#  (891, 'the first computer-generated feature cartoon'),
#  (892, 'first computer-generated feature cartoon'),
#  (893, 'first'),
#  (894, 'computer-generated feature cartoon'),
#  (895, 'computer-generated'),
#  (896, 'feature cartoon'),
#  (897, 'feature'),
#  (898, 'cartoon'),
#  (899, 'to feel like other movies'),
#  (900, 'feel like other movies'),
#  (901, 'feel'),
#  (902, 'like other movies'),
#  (903, 'other movies'),
#  (904, 'other'),
#  (905, 'that makes for some glacial pacing early on'),
#  (906, 'makes for some glacial pacing early on'),
#  (907, 'makes for some glacial pacing'),
#  (908, 'makes'),
#  (909, 'for some glacial pacing'),
#  (910, 'some glacial pacing'),
#  (911, 'glacial pacing'),
#  (912, 'glacial'),
#  (913, 'pacing'),
#  (914, 'early on'),
#  (915, 'early'),
#  (916,
#   "There 's very little sense to what 's going on here , but the makers serve up the cliches with considerable dash ."),
#  (917,
#   "There 's very little sense to what 's going on here , but the makers serve up the cliches with considerable dash"),
#  (918, "There 's very little sense to what 's going on here , but"),
#  (919, "There 's very little sense to what 's going on here ,"),
#  (920, "There 's very little sense to what 's going on here"),
#  (921, "'s very little sense to what 's going on here"),
#  (922, "very little sense to what 's going on here"),
#  (923, 'very little sense'),
#  (924, 'very little'),
#  (925, "to what 's going on here"),
#  (926, "what 's going on here"),
#  (927, "'s going on here"),
#  (928, 'going on here'),
#  (929, 'going on'),
#  (930, 'here'),
#  (931, 'the makers serve up the cliches with considerable dash'),
#  (932, 'the makers'),
#  (933, 'makers'),
#  (934, 'serve up the cliches with considerable dash'),
#  (935, 'serve up'),
#  (936, 'serve'),
#  (937, 'the cliches with considerable dash'),
#  (938, 'the cliches'),
#  (939, 'cliches'),
#  (940, 'with considerable dash'),
#  (941, 'considerable dash'),
#  (942, 'considerable'),
#  (943, 'dash'),
#  (944,
#   'Cattaneo should have followed the runaway success of his first film , The Full Monty , with something different .'),
#  (945, 'Cattaneo'),
#  (946,
#   'should have followed the runaway success of his first film , The Full Monty , with something different .'),
#  (947,
#   'should have followed the runaway success of his first film , The Full Monty , with something different'),
#  (948,
#   'have followed the runaway success of his first film , The Full Monty , with something different'),
#  (949,
#   'followed the runaway success of his first film , The Full Monty , with something different'),
#  (950, 'followed the runaway success of his first film , The Full Monty ,'),
#  (951, 'followed'),
#  (952, 'the runaway success of his first film , The Full Monty ,'),
#  (953, 'the runaway success'),
#  (954, 'runaway success'),
#  (955, 'runaway'),
#  (956, 'success'),
#  (957, 'of his first film , The Full Monty ,'),
#  (958, 'his first film , The Full Monty ,'),
#  (959, 'his first film , The Full Monty'),
#  (960, 'his first film ,'),
#  (961, 'his first film'),
#  (962, 'first film'),
#  (963, 'The Full Monty'),
#  (964, 'Full Monty'),
#  (965, 'Full'),
#  (966, 'Monty'),
#  (967, 'with something different'),
#  (968, 'something different'),
#  (969, 'different'),
#  (970,
#   "They 're the unnamed , easily substitutable forces that serve as whatever terror the heroes of horror movies try to avoid ."),
#  (971, 'They'),
#  (972,
#   "'re the unnamed , easily substitutable forces that serve as whatever terror the heroes of horror movies try to avoid ."),
#  (973,
#   "'re the unnamed , easily substitutable forces that serve as whatever terror the heroes of horror movies try to avoid"),
#  (974, "'re"),
#  (975,
#   'the unnamed , easily substitutable forces that serve as whatever terror the heroes of horror movies try to avoid'),
#  (976, 'the unnamed , easily substitutable forces'),
#  (977, 'unnamed , easily substitutable forces'),
#  (978, 'unnamed , easily substitutable'),
#  (979, 'unnamed'),
#  (980, ', easily substitutable'),
#  (981, 'easily substitutable'),
#  (982, 'easily'),
#  (983, 'substitutable'),
#  (984, 'forces'),
#  (985,
#   'that serve as whatever terror the heroes of horror movies try to avoid'),
#  (986, 'serve as whatever terror the heroes of horror movies try to avoid'),
#  (987, 'as whatever terror the heroes of horror movies try to avoid'),
#  (988, 'whatever terror the heroes of horror movies try to avoid'),
#  (989, 'whatever'),
#  (990, 'terror the heroes of horror movies try to avoid'),
#  (991, 'terror'),
#  (992, 'the heroes of horror movies try to avoid'),
#  (993, 'the heroes of horror movies'),
#  (994, 'the heroes'),
#  (995, 'heroes'),
#  (996, 'of horror movies'),
#  (997, 'horror movies'),
#  (998, 'horror'),
#  (999, 'try to avoid'),
#  ...]

# %% [markdown]
# # Deleting the duplicates and storing all unique phrases and their indices into a dictionary

# %%
unique_phrase_dic = {}

for index, phrase in enumerate(df.phrase):
    if index == 0:
        unique_phrase = phrase
        
        unique_phrase_dic[index] = unique_phrase

    if phrase not in unique_phrase:
        unique_phrase = phrase
    
        unique_phrase_dic[index] = unique_phrase

# %%
unique_phrase_dic
# Out:
# {0: 'A series of escapades demonstrating the adage that what is good for the goose is also good for the gander , some of which occasionally amuses but none of which amounts to much of a story .',
#  63: 'This quiet , introspective and entertaining independent is worth seeking .',
#  81: "Even fans of Ismail Merchant 's work , I suspect , would have a hard time sitting through this one .",
#  116: 'A positively thrilling combination of ethnography and all the intrigue , betrayal , deceit and murder of a Shakespearean tragedy or a juicy soap opera .',
#  156: 'Aggressive self-glorification and a manipulative whitewash .',
#  166: 'A comedy-drama of nearly epic proportions rooted in a sincere performance by the title character undergoing midlife crisis .',
#  198: 'Narratively , Trouble Every Day is a plodding mess .',
#  213: "The Importance of Being Earnest , so thick with wit it plays like a reading from Bartlett 's Familiar Quotations",
#  247: "But it does n't leave you with much .",
#  259: 'You could hate it for the same reason .',
#  271: "There 's little to recommend Snow Dogs , unless one considers cliched dialogue and perverse escapism a source of high hilarity .",
#  306: "Kung Pow is Oedekerk 's realization of his childhood dream to be in a martial-arts flick , and proves that sometimes the dreams of youth should remain just that .",
#  352: 'The performances are an absolute joy .',
#  363: 'Fresnadillo has something serious to say about the ways in which extravagant chance can distort our perspective and throw us off the path of good sense .',
#  407: 'I still like Moonlight Mile , better judgment be damned .',
#  423: 'A welcome relief from baseball movies that try too hard to be mythic , this one is a sweet and modest and ultimately winning story .',
#  458: 'a bilingual charmer , just like the woman who inspired it',
#  473: "Like a less dizzily gorgeous companion to Mr. Wong 's In the Mood for Love -- very much a Hong Kong movie despite its mainland setting .",
#  516: 'As inept as big-screen remakes of The Avengers and The Wild Wild West .',
#  536: "It 's everything you 'd expect -- but nothing more .",
#  551: 'Best indie of the year , so far .',
#  563: "Hatfield and Hicks make the oddest of couples , and in this sense the movie becomes a study of the gambles of the publishing world , offering a case study that exists apart from all the movie 's political ramifications .",
#  619: "It 's like going to a house party and watching the host defend himself against a frothing ex-girlfriend .",
#  647: "That the Chuck Norris `` grenade gag '' occurs about 7 times during Windtalkers is a good indication of how serious-minded the film is .",
#  686: 'The plot is romantic comedy boilerplate from start to finish .',
#  702: 'It arrives with an impeccable pedigree , mongrel pep , and almost indecipherable plot complications .',
#  725: 'A film that clearly means to preach exclusively to the converted .',
#  741: "While The Importance of Being Earnest offers opportunities for occasional smiles and chuckles , it does n't give us a reason to be in the theater beyond Wilde 's wit and the actors ' performances .",
#  786: "The latest vapid actor 's exercise to appropriate the structure of Arthur Schnitzler 's Reigen .",
#  810: "More vaudeville show than well-constructed narrative , but on those terms it 's inoffensive and actually rather sweet .",
#  839: 'Nothing more than a run-of-the-mill action flick .',
#  848: 'Hampered -- no , paralyzed -- by a self-indulgent script ... that aims for poetry and ends up sounding like satire .',
#  881: 'Ice Age is the first computer-generated feature cartoon to feel like other movies , and that makes for some glacial pacing early on .',
#  916: "There 's very little sense to what 's going on here , but the makers serve up the cliches with considerable dash .",
#  944: 'Cattaneo should have followed the runaway success of his first film , The Full Monty , with something different .',
#  970: "They 're the unnamed , easily substitutable forces that serve as whatever terror the heroes of horror movies try to avoid .",
#  1002: 'It almost feels as if the movie is more interested in entertaining itself than in amusing us .',
#  1023: "The movie 's progression into rambling incoherence gives new meaning to the phrase ` fatal script error . '",
#  1050: "Do n't judge this one too soon - it 's a dark , gritty story but it takes off in totally unexpected directions and keeps on going .",
#  1087: 'So could young romantics out on a date .',
#  1099: "Tartakovsky 's team has some freakish powers of visual charm , but the five writers slip into the modern rut of narrative banality .",
#  1134: 'Vincent Gallo is right at home in this French shocker playing his usual bad boy weirdo role .',
#  1164: "If a horror movie 's primary goal is to frighten and disturb , then They works spectacularly well ... A shiver-inducing , nerve-rattling ride .",
#  1198: 'This 100-minute movie only has about 25 minutes of decent material .',
#  1215: 'Fortunately , you still have that option .',
#  1224: 'Less the sensational true-crime hell-jaunt purists might like and more experimental in its storytelling -LRB- though no less horrifying for it -RRB- .',
#  1257: "As tricky and satisfying as any of David Mamet 's airless cinematic shell games .",
#  1280: "I 'm sure the filmmaker would disagree , but , honestly , I do n't see the point .",
#  1304: 'Jones has tackled a meaty subject and drawn engaging characters while peppering the pages with memorable zingers .',
#  1332: 'Bloody Sunday has the grace to call for prevention rather than to place blame , making it one of the best war movies ever made .',
#  1368: 'Takes a clunky TV-movie approach to detailing a chapter in the life of the celebrated Irish playwright , poet and drinker .',
#  1400: "Finally coming down off of Miramax 's deep shelves after a couple of aborted attempts , Waking Up in Reno makes a strong case for letting sleeping dogs lie .",
#  1445: 'Thanks largely to Williams , all the interesting developments are processed in 60 minutes -- the rest is just an overexposed waste of film .',
#  1479: 'Comes across as a relic from a bygone era , and its convolutions ... feel silly rather than plausible .',
#  1505: "Perhaps it 's cliche to call the film ` refreshing , ' but it is .",
#  1522: 'Both lead performances are Oscar-size .',
#  1530: 'Run for your lives !',
#  1538: "Mark Pellington 's latest pop thriller is as kooky and overeager as it is spooky and subtly in love with myth .",
#  1568: "Claude Chabrol 's camera has a way of gently swaying back and forth as it cradles its characters , veiling tension beneath otherwise tender movements .",
#  1608: "Transforms one of -LRB- Shakespeare 's -RRB- deepest tragedies into a smart new comedy .",
#  1627: "The screenplay by James Eric , James Horton and director Peter O'Fallon ... is so pat it makes your teeth hurt .",
#  1658: 'But arriving at a particularly dark moment in history , it offers flickering reminders of the ties that bind us .',
#  1686: 'Its generic villains lack any intrigue -LRB- other than their funny accents -RRB- and the action scenes are poorly delivered .',
#  1715: "The characters are more deeply thought through than in most ` right-thinking ' films .",
#  1734: 'The film , despite the gratuitous cinematic distractions impressed upon it , is still good fun .',
#  1754: "Downright transparent is the script 's endless assault of embarrassingly ham-fisted sex jokes that reek of a script rewrite designed to garner the film a `` cooler '' PG-13 rating .",
#  1798: 'A smart , provocative drama that does the nearly impossible : It gets under the skin of a man we only know as an evil , monstrous lunatic .',
#  1839: "It 's like a drive-by .",
#  1845: "is many things -- stoner midnight flick , sci-fi deconstruction , gay fantasia -- but above all it 's a love story as sanguine as its title .",
#  1882: 'A very funny romantic comedy about two skittish New York middle-agers who stumble into a relationship and then struggle furiously with their fears and foibles .',
#  1917: 'But it has an ambition to say something about its subjects , but not a willingness .',
#  1937: "-LRB- Scherfig -RRB- has made a movie that will leave you wondering about the characters ' lives after the clever credits roll .",
#  1965: '-LRB- An -RRB- absorbing documentary .',
#  1972: 'Reeks of rot and hack work from start to finish .',
#  1983: 'Plays like a series of vignettes -- clips of a film that are still looking for a common through-line .',
#  2006: 'Contrived pastiche of caper',
#  2012: 'The major problem with Windtalkers is that the bulk of the movie centers on the wrong character .',
#  2033: 'Swimfan , like Fatal Attraction , eventually goes overboard with a loony melodramatic denouement in which a high school swimming pool substitutes for a bathtub .',
#  2070: "This is a heartfelt story ... it just is n't a very involving one .",
#  2086: 'An unsettling , memorable cinematic experience that does its predecessors proud .',
#  2101: "All in all , it 's a pretty good execution of a story that 's a lot richer than the ones Hollywood action screenwriters usually come up with on their own .",
#  2141: "Phillip Noyce and all of his actors -- as well as his cinematographer , Christopher Doyle -- understand the delicate forcefulness of Greene 's prose , and it 's there on the screen in their version of The Quiet American .",
#  2194: "The Pianist lacks the quick emotional connections of Steven Spielberg 's Schindler 's List .",
#  2217: 'Inventive , fun , intoxicatingly sexy , violent , self-indulgent and maddening .',
#  2234: 'Tells a fascinating , compelling story .',
#  2243: "Written , flatly , by David Kendall and directed , barely , by There 's Something About Mary co-writer Ed Decter .",
#  2273: 'Highly recommended viewing for its courage , ideas , technical proficiency and great acting .',
#  2296: "In IMAX in short , it 's just as wonderful on the big screen .",
#  2314: "It shows us a slice of life that 's very different from our own and yet instantly recognizable .",
#  2337: 'Amid the shock and curiosity factors , the film is just a corny examination of a young actress trying to find her way .',
#  2368: "It 's lazy for a movie to avoid solving one problem by trying to distract us with the solution to another .",
#  2393: "... it 's as comprehensible as any Dummies guide , something even non-techies can enjoy .",
#  2413: 'Entertains not so much because of its music or comic antics , but through the perverse pleasure of watching Disney scrape the bottom of its own cracker barrel .',
#  2452: 'Writer\\/director Burr Steers emphasizes the Q in Quirky , with mixed results .',
#  2472: 'Scarcely worth a mention apart from reporting on the number of tumbleweeds blowing through the empty theatres graced with its company .',
#  2503: 'Invigorating , surreal , and resonant with a rainbow of emotion .',
#  2519: "`` Analyze That '' is one of those crass , contrived sequels that not only fails on its own , but makes you second-guess your affection for the original .",
#  2555: "Report card : Does n't live up to the exalted tagline - there 's definite room for improvement .",
#  2580: "It 's not a particularly good film , but neither is it a monsterous one .",
#  2597: 'Tsai may be ploughing the same furrow once too often .',
#  2613: "-LRB- Green is -RRB- the comedy equivalent of Saddam Hussein , and I 'm just about ready to go to the U.N. and ask permission for a preemptive strike .",
#  2653: "A surprisingly ` solid ' achievement by director Malcolm D. Lee and writer John Ridley .",
#  2677: "Massoud 's story is an epic , but also a tragedy , the record of a tenacious , humane fighter who was also the prisoner -LRB- and ultimately the victim -RRB- of history .",
#  2718: 'Changing Lanes tries for more .',
#  2726: 'Shyamalan should stop trying to please his mom .',
#  2738: 'A macabre and very stylized Swedish fillm about a modern city where all the religious and civic virtues that hold society in place are in tatters .',
#  2776: "One of recent memory 's most thoughtful films about art , ethics , and the cost of moral compromise .",
#  2803: 'The narrative is so consistently unimaginative that probably the only way to have saved the film is with the aid of those wisecracking Mystery Science Theater 3000 guys .',
#  2840: 'Filmmaker Tian Zhuangzhuang triumphantly returns to narrative filmmaking with a visually masterful work of quiet power .',
#  2864: 'A mawkish self-parody that plays like some weird Masterpiece Theater sketch with neither a point of view nor a compelling reason for being .',
#  2894: "Takes one character we do n't like and another we do n't believe , and puts them into a battle of wills that is impossible to care about and is n't very funny .",
#  2929: "And if you appreciate the one-sided theme to Lawrence 's over-indulgent tirade , then knock yourself out and enjoy the big screen postcard that is a self-glorified Martin Lawrence lovefest .",
#  2971: 'The whole film has this sneaky feel to it -- as if the director is trying to dupe the viewer into taking it all as Very Important simply because the movie is ugly to look at and not a Hollywood product .',
#  3021: 'Whenever it threatens to get bogged down in earnest dramaturgy , a stirring visual sequence like a surge through swirling rapids or a leap from pinnacle to pinnacle rouses us .',
#  3064: 'Swinging , the film makes it seem , is not a hobby that attracts the young and fit .',
#  3086: "But when it does , you 're entirely unprepared .",
#  3098: 'Devos delivers a perfect performance that captures the innocence and budding demons within a wallflower .',
#  3122: '300 years of Russian history and culture compressed into an evanescent , seamless and sumptuous stream of consciousness .',
#  3150: 'The filmmakers want nothing else than to show us a good time , and in their cheap , B movie way , they succeed .',
#  3180: 'Mr. Polanski is in his element here : alone , abandoned , but still consoled by his art , which is more than he has ever revealed before about the source of his spiritual survival .',
#  3225: '`` Spider-man is better than any summer blockbuster we had to endure last summer , and hopefully , sets the tone for a summer of good stuff .',
#  3262: 'Absorbing character',
#  3263: 'Turpin',
#  3264: 'Violent , vulgar and forgettably entertaining .',
#  3272: "It 's the unsettling images of a war-ravaged land that prove more potent and riveting than the unlikely story of Sarah and Harrison .",
#  3304: 'Winds up being both revelatory and narcissistic , achieving some honest insight into relationships that most high-concept films candy-coat with pat storylines , precious circumstances and beautiful stars .',
#  3346: "If Mostly Martha is mostly unsurprising , it 's still a sweet , even delectable diversion .",
#  3367: 'A thoughtful and surprisingly affecting portrait of a screwed-up man who dared to mess with some powerful people , seen through the eyes of the idealistic kid who chooses to champion his ultimately losing cause .',
#  3416: 'Keenly observed and refreshingly natural , Swimming gets the details right , from its promenade of barely clad bodies in Myrtle Beach , S.C. , to the adrenaline jolt of a sudden lunch rush at the diner .',
#  3470: 'A brilliant gag at the expense of those who paid for it and those who pay to see it .',
#  3492: 'A triumph , a film that hews out a world and carries us effortlessly from darkness to light .',
#  3515: 'Just about everyone involved here seems to be coasting .',
#  3528: 'A fascinating , dark thriller that keeps you hooked on the delicious pulpiness of its lurid fiction .',
#  3550: 'I suspect this is the kind of production that would have been funnier if the director had released the outtakes theatrically and used the film as a bonus feature on the DVD .',
#  3590: "It 's hard to say who might enjoy this , are there Tolstoy groupies out there ?",
#  3609: 'Daughter From Danang reveals that efforts toward closure only open new wounds .',
#  3629: "One of the year 's most weirdly engaging and unpredictable character pieces .",
#  3642: 'Intriguing and downright intoxicating .',
#  3648: "Although fairly involving as far as it goes , the film does n't end up having much that is fresh to say about growing up Catholic or , really , anything .",
#  3686: "The movie is silly beyond comprehension , and even if it were n't silly , it would still be beyond comprehension .",
#  3707: 'Sleek and arty .',
#  3712: 'Poor editing , bad bluescreen , and ultra-cheesy dialogue highlight the radical action .',
#  3731: "-LRB- Cho 's face is -RRB- an amazing slapstick instrument , creating a scrapbook of living mug shots .",
#  3759: 'It gets the details of its time frame right but it completely misses its emotions .',
#  3777: 'Initial strangeness inexorably gives way to rote sentimentality and mystical tenderness becomes narrative expedience .',
#  3799: 'It lets you brush up against the humanity of a psycho , without making him any less psycho .',
#  3823: "Like the world of his film , Hartley created a monster but did n't know how to handle it .",
#  3847: 'When cowering and begging at the feet a scruffy Giannini , Madonna gives her best performance since Abel Ferrara had her beaten to a pulp in his Dangerous Game .',
#  3889: 'Too clumsy in key moments ... to make a big splash .',
#  3904: "Because Eight Legged Freaks is partly an homage to Them , Tarantula and other low - budget B-movie thrillers of the 1950s and '60s , the movie is a silly -LRB- but not sophomoric -RRB- romp through horror and hellish conditions .",
#  3960: 'It feels like very light Errol Morris , focusing on eccentricity but failing , ultimately , to make something bigger out of its scrapbook of oddballs .',
#  3993: "Spielberg 's realization of a near-future America is masterful .",
#  4003: "There 's a scientific law to be discerned here that producers would be well to heed : Mediocre movies start to drag as soon as the action speeds up ; when the explosions start , they fall to pieces .",
#  4053: "He 's one of the few ` cool ' actors who never seems aware of his own coolness .",
#  4076: 'Feels like the work of an artist who is simply tired -- of fighting the same fights , of putting the weight of the world on his shoulders , of playing with narrative form .',
#  4117: '... stale and uninspired .',
#  4123: "In the director 's cut , the film is not only a love song to the movies but it also is more fully an example of the kind of lush , all-enveloping movie experience it rhapsodizes .",
#  4163: 'Has the rare capability to soothe and break your heart with a single stroke .',
#  4184: 'Eerily accurate depiction of depression .',
#  4193: 'As a feature-length film , it wears out its welcome as tryingly as the title character .',
#  4212: "An uncluttered , resonant gem that relays its universal points without lectures or confrontations . '",
#  4234: 'The story alone could force you to scratch a hole in your head .',
#  4251: "It 's the filmmakers ' post-camp comprehension of what made old-time B movies good-bad that makes Eight Legged Freaks a perfectly entertaining summer diversion .",
#  4277: 'As any creature-feature fan knows , when you cross toxic chemicals with a bunch of exotic creatures , you get a lot of running around , screaming and death .',
#  4318: "You bet there is and it 's what makes this rather convoluted journey worth taking .",
#  4336: "Before it takes a sudden turn and devolves into a bizarre sort of romantic comedy , Steven Shainberg 's adaptation of Mary Gaitskill 's harrowing short story ... is a brilliantly played , deeply unsettling experience .",
#  4381: 'Kim Ki-Deok seems to have in mind an -LRB- emotionally at least -RRB- adolescent audience demanding regular shocks and bouts of barely defensible sexual violence to keep it interested .',
#  4425: 'Has no reason to exist , other than to employ Hollywood kids and people who owe favors to their famous parents .',
#  4453: 'A well-made but emotionally scattered film whose hero gives his heart only to the dog .',
#  4473: 'Those who love Cinema Paradiso will find the new scenes interesting , but few will find the movie improved .',
#  4494: 'Campanella gets the tone just right -- funny in the middle of sad in the middle of hopeful .',
#  4514: 'Nothing more than an amiable but unfocused bagatelle that plays like a loosely-connected string of acting-workshop exercises .',
#  4538: "It 's a sharp movie about otherwise dull subjects .",
#  4549: 'Wallace gets a bit heavy handed with his message at times , and has a visual flair that waxes poetic far too much for our taste .',
#  4584: 'Charming and funny -LRB- but ultimately silly -RRB- movie .',
#  4594: "... the one thing this Wild film has that other Imax films do n't : chimps , lots of chimps , all blown up to the size of a house .",
#  4627: 'Starts out mediocre , spirals downward , and thuds to the bottom of the pool with an utterly incompetent conclusion .',
#  4653: "This is a children 's film in the truest sense .",
#  4665: "Horrendously amateurish filmmaking that is plainly dull and visually ugly when it is n't incomprehensible .",
#  4683: 'Beautifully crafted , engaging filmmaking that should attract upscale audiences hungry for quality and a nostalgic , twisty yarn that will keep them guessing .',
#  4718: 'An awkwardly contrived exercise in magic realism .',
#  4728: 'The punch lines that miss , unfortunately , outnumber the hits by three-to-one .',
#  4748: 'Like Smoke Signals , the film is also imbued with strong themes of familial ties and spirituality that are powerful and moving without stooping to base melodrama',
#  4782: "Evokes the style and flash of the double-cross that made Mamet 's `` House of Games '' and last fall 's `` Heist '' so much fun .",
#  4812: 'The film aims to be funny , uplifting and moving , sometimes all at once .',
#  4827: 'At a brief 42 minutes , we need more X and less blab .',
#  4845: 'The Spalding Gray equivalent of a teen gross-out comedy .',
#  4858: "There 's a great deal of corny dialogue and preposterous moments .",
#  4871: 'Uneven but a lot of fun .',
#  4877: 'The result might look like Vulgar .',
#  4884: "The film rehashes several old themes and is capped with pointless extremes -- it 's insanely violent and very graphic .",
#  4911: "The dragons are the real stars of Reign of Fire and you wo n't be disappointed .",
#  4933: 'It never plays as dramatic even when dramatic things happen to people .',
#  4947: 'Manages to please its intended audience -- children -- without placing their parents in a coma-like state .',
#  4969: 'The movie generates plot points with a degree of randomness usually achieved only by lottery drawing .',
#  4990: 'Though the film never veers from its comic course , its unintentional parallels might inadvertently evoke memories and emotions which are anything but humorous .',
#  5021: 'The film can depress you about life itself .',
#  5029: "If you saw it on TV , you 'd probably turn it off , convinced that you had already seen that movie .",
#  5055: 'You get the impression that writer and director Burr Steers knows the territory ... but his sense of humor has yet to lose the smug self-satisfaction usually associated with the better private schools .',
#  5096: 'This is a superior horror flick .',
#  5103: "The movie 's heavy-handed screenplay navigates a fast fade into pomposity and pretentiousness .",
#  5120: "A little weak -- and it is n't that funny .",
#  5130: "But they do n't fit well together and neither is well told .",
#  5143: 'Being latently gay and liking to read are hardly enough .',
#  5158: 'More sophisticated and literate than such pictures usually are ... an amusing little catch .',
#  5177: 'Storytelling feels slight .',
#  5181: 'Monte Cristo smartly emphasizes the well-wrought story and omits needless chase scenes and swordfights as the revenge unfolds .',
#  5209: "It 's a fairy tale that comes from a renowned Indian film culture that allows Americans to finally revel in its splendor .",
#  5239: 'Well-done supernatural thriller with keen insights into parapsychological phenomena and the soulful nuances of the grieving process .',
#  5266: '... only Bond can save us from the latest eccentric , super-wealthy megalomaniac bent on world domination and destruction .',
#  5293: 'It is depressing , ruthlessly pained and depraved , the movie equivalent of staring into an open wound .',
#  5317: 'Damon brings the proper conviction to his role as -LRB- Jason Bourne -RRB- .',
#  5336: 'Parents beware ; this is downright movie penance .',
#  5346: "When it 's this rich and luscious , who cares ?",
#  5359: 'A singularly off-putting romantic comedy .',
#  5366: 'Director Boris von Sychowski instead opts for a routine slasher film that was probably more fun to make than it is to sit through .',
#  5398: "Would 've been nice if the screenwriters had trusted audiences to understand a complex story , and left off the film 's predictable denouement .",
#  5428: "A superfluous sequel ... plagued by that old familiar feeling of ` let 's get this thing over with ' : Everyone has shown up at the appointed time and place , but visible enthusiasm is mighty hard to find .",
#  5479: "An earnest , roughshod document , it serves as a workable primer for the region 's recent history , and would make a terrific 10th-grade learning tool .",
#  5516: 'Cloaks a familiar anti-feminist equation -LRB- career - kids = misery -RRB- in tiresome romantic-comedy duds .',
#  5541: "A film that plays things so nice 'n safe as to often play like a milquetoast movie of the week blown up for the big screen .",
#  5568: 'His work transcends the boy-meets-girl posturing of typical love stories .',
#  5583: 'An even more predictable , cliche-ridden endeavor than its predecessor .',
#  5596: "Plays like a bad blend of an overripe episode of TV 's Dawson 's Creek and a recycled and dumbed-down version of Love Story .",
#  5626: "The script covers huge , heavy topics in a bland , surfacey way that does n't offer any insight into why , for instance , good things happen to bad people .",
#  5664: "The film is so bad it does n't improve upon the experience of staring at a blank screen .",
#  5682: "They threw loads of money at an idea that should 've been so much more even if it was only made for teenage boys and wrestling fans .",
#  5716: "It 's difficult to imagine that a more confused , less interesting and more sloppily made film could possibly come down the road in 2002 .",
#  5748: 'Though the film is well-intentioned , one could rent the original and get the same love story and parable .',
#  5767: 'Jolting into Charleston rhythms , the story has the sizzle of old news that has finally found the right vent -LRB- accurate ?',
#  5795: 'Or both .',
#  5797: 'Williams plays Sy , another of his open-faced , smiling madmen , like the killer in Insomnia .',
#  5820: 'Phoned-in business as usual .',
#  5826: 'With its lackadaisical plotting and mindless action , All About the Benjamins evokes the bottom tier of blaxploitation flicks from the 1970s .',
#  5856: 'Ah , yes , that would be me : fighting off the urge to doze .',
#  5876: 'Thoughtless , random , superficial humour and a lot of very bad Scouse accents',
#  5893: 'In an era where big stars and high production values are standard procedure , Narc strikes a defiantly retro chord , and outpaces its contemporaries with daring and verve .',
#  5934: "A rip-roaring comedy action fest that 'll put hairs on your chest .",
#  5952: '... a thoughtful what-if for the heart as well as the mind .',
#  5963: "Miyazaki is one of world cinema 's most wondrously gifted artists and storytellers .",
#  5981: "A chronicle not only of one man 's quest to be president , but of how that man single-handedly turned a plane full of hard-bitten , cynical journalists into what was essentially , by campaign 's end , an extended publicity department .",
#  6036: "Provides the kind of ` laugh therapy ' I need from movie comedies -- offbeat humor , amusing characters , and a happy ending .",
#  6066: 'Feels strangely hollow at its emotional core .',
#  6076: "At a time when commercialism has squeezed the life out of whatever idealism American moviemaking ever had , Godfrey Reggio 's career shines like a lonely beacon .",
#  6111: "Director Roger Michell does so many of the little things right that it 's difficult not to cuss him out severely for bungling the big stuff .",
#  6142: "Robert Harmon 's less-is-more approach delivers real bump-in - the-night chills -- his greatest triumph is keeping the creepy crawlies hidden in the film 's thick shadows .",
#  6179: "This movie may not have the highest production values you 've ever seen , but it 's the work of an artist , one whose view of America , history and the awkwardness of human life is generous and deep .",
#  6220: 'Feral and uncomfortable .',
#  6225: 'Sillier , cuter , and shorter than the first -LRB- as best I remember -RRB- , but still a very good time at the cinema .',
#  6253: "It 's more enjoyable than I expected , though , and that 's because the laughs come from fairly basic comedic constructs .",
#  6281: 'Black-and-white and unrealistic .',
#  6286: 'The film is predictable in the reassuring manner of a beautifully sung holiday carol .',
#  6304: 'The only camouflage Carvey should now be considering is a paper bag to wear over his head when he goes out into public , to avoid being recognized as the man who bilked unsuspecting moviegoers .',
#  6351: 'Not about scares but a mood in which an ominous , pervasive , and unknown threat lurks just below the proceedings and adds an almost constant mindset of suspense .',
#  6390: 'Some of the computer animation is handsome , and various amusing sidekicks add much-needed levity to the otherwise bleak tale , but overall the film never rises above mediocrity .',
#  6430: 'Offers the flash of rock videos fused with solid performances and eerie atmosphere .',
#  6448: 'A breezy blend of art , history , esoteric musings and philosophy .',
#  6464: "Now as a former Gong Show addict , I 'll admit it , my only complaint is that we did n't get more re-creations of all those famous moments from the show .",
#  6502: 'Genuinely unnerving .',
#  6506: 'The increasingly diverse French director has created a film that one can honestly describe as looking , sounding and simply feeling like no other film in recent history .',
#  6535: 'One of those joyous films that leaps over national boundaries and celebrates universal human nature .',
#  6556: 'A difficult but worthy film that bites off more than it can chew by linking the massacre of Armenians in 1915 with some difficult relationships in the present .',
#  6592: 'Halfway through the movie , the humor dwindles .',
#  6601: 'Witty and often surprising , a dark little morality tale disguised as a romantic comedy .',
#  6619: 'One senses in World Traveler and in his earlier film that Freundlich bears a grievous but obscure complaint against fathers , and circles it obsessively , without making contact .',
#  6659: 'In fact , even better .',
#  6665: '... a preachy parable stylized with a touch of John Woo bullet ballet .',
#  6683: "Proves that some movie formulas do n't need messing with -- like the big-bug movie .",
#  6700: 'An uplifting , largely bogus story .',
#  6707: 'Thanks to confident filmmaking and a pair of fascinating performances , the way to that destination is a really special walk in the woods .',
#  6737: 'Superbly photographed and staged by Mendes with a series of riveting set pieces the likes of which mainstream audiences have rarely seen .',
#  6765: 'A mesmerizing cinematic poem from the first frame to the last .',
#  6778: 'After the first 10 minutes , which is worth seeing',
#  6788: 'sinks',
#  6789: 'an abyss',
#  6791: 'bad alternative music',
#  6794: "It has become apparent that the franchise 's best years are long past .",
#  6812: "Screenwriter Chris ver Weil 's directing debut is good-natured and never dull , but its virtues are small and easily overshadowed by its predictability .",
#  6846: "Too much of Storytelling moves away from Solondz 's social critique , casting its audience as that of intellectual lector in contemplation of the auteur 's professional injuries .",
#  6885: "Ultimately , Sarah 's dedication to finding her husband seems more psychotic than romantic , and nothing in the movie makes a convincing case that one woman 's broken heart outweighs all the loss we witness .",
#  6929: 'The jokes are flat , and the action looks fake .',
#  6941: 'A mildly enjoyable if toothless adaptation of a much better book .',
#  6955: "Festers in just such a dungpile that you 'd swear you were watching monkeys flinging their feces at you .",
#  6980: 'In addition to the overcooked , ham-fisted direction , which has all the actors reaching for the back row , the dialogue sounds like horrible poetry .',
#  7013: "A vile , incoherent mess ... a scummy ripoff of David Cronenberg 's brilliant ` Videodrome . '",
#  7036: "First , for a movie that tries to be smart , it 's kinda dumb .",
#  7052: 'I was sent a copyof this film to review on DVD .',
#  7066: '... silly humbuggery ...',
#  7070: "Is n't as sharp as the original ... Despite some visual virtues , ` Blade II ' just does n't cut it .",
#  7091: 'A smart , arch and rather cold-blooded comedy .',
#  7101: '-LRB- A -RRB- rather thinly-conceived movie .',
#  7108: 'Its flame-like , roiling black-and-white inspires trembling and gratitude .',
#  7122: "Robinson 's web of suspense matches the page-turning frenzy that Clancy creates .",
#  7140: 'A slight but sweet film .',
#  7145: 'Got a David Lynch jones ?',
#  7152: 'Earnest and tentative even when it aims to shock .',
#  7162: 'Time of Favor could have given audiences the time of day by concentrating on the elements of a revealing alienation among a culture of people who sadly are at hostile odds with one another through recklessness and retaliation .',
#  7212: "`` Austin Powers in Goldmember '' has the right stuff for silly summer entertainment and has enough laughs to sustain interest to the end .",
#  7241: "What puzzles me is the lack of emphasis on music in Britney Spears ' first movie .",
#  7261: 'The filmmakers might want to look it up .',
#  7268: "While maintaining the appearance of clinical objectivity , this sad , occasionally horrifying but often inspiring film is among Wiseman 's warmest .",
#  7297: 'There is simply no doubt that this film asks the right questions at the right time in the history of our country .',
#  7322: 'A dreary movie .',
#  7326: "Sadly , though many of the actors throw off a spark or two when they first appear , they ca n't generate enough heat in this cold vacuum of a comedy to start a reaction .",
#  7368: "To the filmmakers , Ivan is a prince of a fellow , but he comes across as shallow and glib though not mean-spirited , and there 's no indication that he 's been responsible for putting together any movies of particular value or merit .",
#  7421: 'Using a stock plot , About a Boy injects just enough freshness into the proceedings to provide an enjoyable 100 minutes in a movie theater .',
#  7451: 'Beating the Austin Powers films at their own game , this blaxploitation spoof downplays the raunch in favor of gags that rely on the strength of their own cleverness as opposed to the extent of their outrageousness .',
#  7499: 'What begins as a conventional thriller evolves into a gorgeously atmospheric meditation on life-changing chance encounters .',
#  7523: 'Buy popcorn .',
#  7527: 'A late-night cable sexploitation romp masquerading as a thriller about the ruthless social order that governs college cliques .',
#  7554: "A well-intentioned effort that 's still too burdened by the actor 's offbeat sensibilities for the earnest emotional core to emerge with any degree of accessibility .",
#  7583: "-LRB- Allen 's -RRB- been making piffle for a long while , and Hollywood Ending may be his way of saying that piffle is all that the airhead movie business deserves from him right now .",
#  7623: "Seeing as the film lacks momentum and its position remains mostly undeterminable , the director 's experiment is a successful one .",
#  7647: "Judith and Zaza 's extended bedroom sequence ... is so intimate and sensual and funny and psychologically self-revealing that it makes most of what passes for sex in the movies look like cheap hysterics .",
#  7689: 'Uneven performances and a spotty script add up to a biting satire that has no teeth .',
#  7707: '... irritating soul-searching garbage .',
#  7714: 'A solid , spooky entertainment worthy of the price of a ticket .',
#  7728: 'Ultimately , clarity matters , both in breaking codes and making movies .',
#  7744: 'In comparison to his earlier films it seems a disappointingly thin slice of lower-class London life ; despite the title ... amounts to surprisingly little .',
#  7773: 'Proves mainly that South Korean filmmakers can make undemanding action movies with all the alacrity of their Hollywood counterparts .',
#  7798: "Except it 's much , much better .",
#  7805: 'It is a happy , heady jumble of thought and storytelling , an insane comic undertaking that ultimately coheres into a sane and breathtakingly creative film .',
#  7839: 'There is more than one joke about putting the toilet seat down .',
#  7854: 'has -RRB-',
#  7855: 'created a substantive movie out of several cliched movie structures : the road movie , the coming-of-age movie , and the teenage sex comedy .',
#  7882: 'So original in its base concept that you can not help but get caught up .',
#  7900: 'It appears to have been made by people to whom the idea of narrative logic or cohesion is an entirely foreign concept .',
#  7927: "If you ignore the cliches and concentrate on City by the Sea 's interpersonal drama , it ai n't half-bad .",
#  7952: 'A dreadful day in Irish history is given passionate , if somewhat flawed , treatment .',
#  7972: 'See it .',
#  7973: 'Nothing but an episode of Smackdown !',
#  7980: 'A guilty pleasure at best , and not worth seeing unless you want to laugh at it .',
#  7998: "Perhaps a better celebration of these unfairly dismissed heroes would be a film that is n't this painfully forced , false and fabricated .",
#  8027: 'A relative letdown .',
#  8032: "` Hey Arnold ! '",
#  8038: 'But though he only scratches the surface , at least he provides a strong itch to explore more .',
#  8059: "The band performances featured in Drumline are red hot ... -LRB- but -RRB- from a mere story point of view , the film 's ice cold .",
#  8089: 'A non-mystery mystery .',
#  8093: 'Leigh is one of the rare directors who feels acting is the heart and soul of cinema .',
#  8113: 'The cast delivers without sham the raw-nerved story .',
#  8124: 'This is a monumental achievement in practically every facet of inept filmmaking : joyless , idiotic , annoying , heavy-handed , visually atrocious , and often downright creepy .',
#  8159: "The filmmaker 's heart is in the right place ...",
#  8168: "One of the most highly-praised disappointments I 've had the misfortune to watch in quite some time .",
#  8190: "Rock 's stand-up magic wanes .",
#  8197: 'Roman Polanski directs The Pianist like a surgeon mends a broken heart ; very meticulously but without any passion .',
#  8220: "Sadly , ` Garth ' has n't progressed as nicely as ` Wayne . '",
#  8238: "With wit and empathy to spare , waydowntown acknowledges the silent screams of workaday inertia but stops short of indulging its characters ' striving solipsism .",
#  8274: 'It labours as storytelling .',
#  8279: 'Remember back when thrillers actually thrilled ?',
#  8286: "The otherwise good-naturedness of Mr. Deeds , with its embrace of sheer goofiness and cameos of less - than-likely New York celebrities ... certainly raises the film above anything Sandler 's been attached to before .",
#  8332: 'Fails so fundamentally on every conventional level that it achieves some kind of goofy grandeur .',
#  8352: '... a ho-hum affair , always watchable yet hardly memorable .',
#  8366: "I just saw this movie ... well , it 's probably not accurate to call it a movie .",
#  8382: "Though uniformly well acted , especially by young Ballesta and Galan -LRB- a first-time actor -RRB- , writer\\/director Achero Manas 's film is schematic and obvious .",
#  8418: 'When you resurrect a dead man , Hard Copy should come a-knocking , no ?',
#  8436: 'If the idea of the white man arriving on foreign shores to show wary natives the true light is abhorrent to you , the simplistic Heaven will quite likely be more like hell .',
#  8478: "It 's hard to believe that a relationship like Holly and Marina 's could survive the hothouse emotions of teendom , and its longevity gets more inexplicable as the characterizations turn more crassly reductive .",
#  8521: "For a movie audience , The Hours does n't connect in a neat way , but introduces characters who illuminate mysteries of sex , duty and love .",
#  8554: 'Purports to be a Hollywood satire but winds up as the kind of film that should be the target of something deeper and more engaging .',
#  8580: 'Too clever by about nine-tenths .',
#  8586: "This is no `` Waterboy ! ''",
#  8593: "They 're going through the motions , but the zip is gone .",
#  8608: "The script 's snazzy dialogue establishes a realistic atmosphere that involves us in the unfolding crisis , but the lazy plotting ensures that little of our emotional investment pays off .",
#  8644: 'Not as good as the original , but what is ...',
#  8651: "Those moviegoers who would automatically bypass a hip-hop documentary should give `` Scratch '' a second look .",
#  8672: 'Bigelow offers some flashy twists and turns that occasionally fortify this turgid fable .',
#  8692: 'An unsophisticated sci-fi drama that takes itself all too seriously .',
#  8704: 'Stupid , infantile , redundant , sloppy , over-the-top , and amateurish .',
#  8721: "Resident Evil is what comes from taking John Carpenter 's Ghosts of Mars and eliminating the beheadings .",
#  8744: 'The movie resolutely avoids all the comic possibilities of its situation , and becomes one more dumb high school comedy about sex gags and prom dates .',
#  8775: 'With or without the sex , a wonderful tale of love and destiny , told well by a master storyteller',
#  8797: 'Though it goes further than both , anyone who has seen The Hunger or Cat People will find little new here , but a tasty performance from Vincent Gallo lifts this tale of cannibal lust above the ordinary .',
#  8843: 'A terrific date movie , whatever your orientation .',
#  8852: "Once the expectation of laughter has been quashed by whatever obscenity is at hand , even the funniest idea is n't funny .",
#  8879: 'How do you make a movie with depth about a man who lacked any ?',
#  8893: "Translation : ` We do n't need to try very hard . '",
#  8905: "`` Frailty '' offers chills much like those that you get when sitting around a campfire around midnight , telling creepy stories to give each other the willies .",
#  8938: 'Less front-loaded and more shapely than the two-hour version released here in 1990 .',
#  8955: "An ambitious movie that , like Shiner 's organizing of the big fight , pulls off enough of its effects to make up for the ones that do n't come off .",
#  8990: 'Some movies suck you in despite their flaws , and Heaven is one such beast .',
#  9008: 'Very well written and directed with brutal honesty and respect for its audience .',
#  9023: "Twenty years after its first release , E.T. remains the most wondrous of all Hollywood fantasies -- and the apex of Steven Spielberg 's misunderstood career .",
#  9054: 'Gooding offers a desperately ingratiating performance .',
#  9063: '... stumbles over every cheap trick in the book trying to make the outrage come even easier .',
#  9084: "Nicely combines the enigmatic features of ` Memento ' with the hallucinatory drug culture of ` Requiem for a Dream . '",
#  9111: 'Every individual will see the movie through the prism of his or her own beliefs and prejudices , but the one thing most will take away is the sense that peace is possible .',
#  9148: "Just a bunch of good actors flailing around in a caper that 's neither original nor terribly funny .",
#  9167: 'This ill-conceived and expensive project winds up looking like a bunch of talented thesps slumming it .',
#  9187: "Broder 's screenplay is shallow , offensive and redundant , with pitifully few real laughs .",
#  9205: 'Leguizamo and Jones are both excellent and the rest of the cast is uniformly superb .',
#  9221: "Trying to figure out the rules of the Country Bear universe -- when are bears bears and when are they like humans , only hairier -- would tax Einstein 's brain .",
#  9261: "`` Feardotcom '' has the makings of an interesting meditation on the ethereal nature of the internet and the otherworldly energies it could channel , but it simply becomes a routine shocker .",
#  9300: 'Delia , Greta , and Paula rank as three of the most multilayered and sympathetic female characters of the year .',
#  9325: "The beauty of Alexander Payne 's ode to the Everyman is in the details .",
#  9343: 'The town has kind of an authentic feel , but each one of these people stand out and everybody else is in the background and it just seems manufactured to me and artificial .',
#  9383: "Julie Davis is the Kathie Lee Gifford of film directors , sadly proving once again ego does n't always go hand in hand with talent .",
#  9415: 'Much credit must be given to the water-camera operating team of Don King , Sonny Miller , and Michael Stewart .',
#  9445: 'In this film , Aussie David Caesar channels the not-quite-dead career of Guy Ritchie .',
#  9464: 'As averse as I usually am to feel-good , follow-your-dream Hollywood fantasies , this one got to me .',
#  9484: "Maybe it is formula filmmaking , but there 's nothing wrong with that if the film is well-crafted and this one is .",
#  9507: 'Would you laugh if a tuba-playing dwarf rolled down a hill in a trash can ?',
#  9527: 'Loses its sense of humor in a vat of failed jokes , twitchy acting , and general boorishness .',
#  9550: 'This misty-eyed Southern nostalgia piece , in treading the line between sappy and sanguine , winds up mired in tear-drenched quicksand .',
#  9581: 'To be oblivious to the existence of this film would be very sweet indeed .',
#  9597: 'Despite its flaws ... Belinsky is still able to create an engaging story that keeps you guessing at almost every turn .',
#  9620: 'A porn film without the sex scenes .',
#  9628: "The movie plays up the cartoon 's more obvious strength of snazziness while neglecting its less conspicuous writing strength .",
#  9650: "Notwithstanding my problem with the movie 's final half hour , I 'm going to recommend SECRETARY , based on the wonderful acting clinic put on by Spader and Gyllenhaal , and also the unique way Shainberg goes about telling what at heart is a sweet little girl -",
#  9707: "Despite slick production values and director Roger Michell 's tick-tock pacing , the final effect is like having two guys yelling in your face for two hours .",
#  9737: "`` Barbershop '' is a good-hearted ensemble comedy with a variety of quirky characters and an engaging story .",
#  9757: 'A soulless jumble of ineptly assembled cliches and pabulum that plays like a 95-minute commercial for NBA properties .',
#  9783: 'An ambitious , serious film that manages to do virtually everything wrong ; sitting through it is something akin to an act of cinematic penance .',
#  9811: 'Consistently clever and suspenseful .',
#  9816: 'Soderbergh skims the fat from the 1972 film .',
#  9828: 'Hilarious musical comedy though stymied by accents thick as mud .',
#  9842: 'A movie like The Guys is why film criticism can be considered work .',
#  9856: 'Anyone who suffers through this film deserves , at the very least , a big box of consolation candy .',
#  9878: 'Bearable .',
#  9880: 'Cremaster 3 is at once a tough pill to swallow and a minor miracle of self-expression .',
#  9903: 'But Kouyate elicits strong performances from his cast , and he delivers a powerful commentary on how governments lie , no matter who runs them .',
#  9934: 'See it for his performance if nothing else .',
#  9940: 'The asylum material is gripping , as are the scenes of Jia with his family .',
# ...
#  18836: "Ultimately this is a frustrating patchwork : an uneasy marriage of Louis Begley 's source novel -LRB- About Schmidt -RRB- and an old Payne screenplay .",
#  18866: "The movie is like a year late for tapping into our reality tv obsession , and even tardier for exploiting the novelty of the `` webcast . ''",
#  18899: "Chai 's structure and pacing are disconcertingly slack .",
#  18909: 'Or else a doggie winks .',
#  18916: "You need n't be steeped in '50s sociology , pop culture or movie lore to appreciate the emotional depth of Haynes ' work .",
#  18942: 'Decasia is what has happened already to so many silent movies , newsreels and the like .',
#  18961: 'More than anything else , Kissing Jessica Stein injects freshness and spirit into the romantic comedy genre , which has been held hostage by generic scripts that seek to remake Sleepless in Seattle again and again .',
#  19005: "Fast and funny , an action cartoon that 's suspenseful enough for older kids but not too scary for the school-age crowd .",
#  19028: 'After all the big build-up , the payoff for the audience , as well as the characters , is messy , murky , unsatisfying .',
#  19053: 'Not only better than its predecessor , it may rate as the most magical and most fun family fare of this or any recent holiday season .',
#  19079: 'Once again , the intelligence of gay audiences has been grossly underestimated , and a meaty plot and well-developed characters have been sacrificed for skin and flash that barely fizzle .',
#  19114: 'A film without surprise geared toward maximum comfort and familiarity .',
#  19127: 'Definitely a crowd-pleaser , but then , so was the Roman Colosseum .',
#  19141: "Here is a VH1 Behind the Music special that has something a little more special behind it : music that did n't sell many records but helped change a nation .",
#  19173: 'Kids will love its fantasy and adventure , and grownups should appreciate its whimsical humor .',
#  19190: 'After all , he took three minutes of dialogue , 30 seconds of plot and turned them into a 90-minute movie that feels five hours long .',
#  19219: 'Interminably bleak , to say nothing of boring .',
#  19228: "A naturally funny film , Home Movie makes you crave Chris Smith 's next movie .",
#  19246: "The Bai brothers have taken an small slice of history and opened it up for all of us to understand , and they 've told a nice little story in the process .",
#  19279: 'A Meatballs for the bare-midriff generation .',
#  19288: 'This movie is about the worst thing Chan has done in the United States .',
#  19302: 'Maintains your interest until the end and even leaves you with a few lingering animated thoughts .',
#  19319: "From blushing to gushing -- Imamura squirts the screen in ` Warm Water Under a Red Bridge '",
#  19341: "Entertainment more disposable than Hanna-Barbera 's half-hour cartoons ever were .",
#  19354: "The beautiful images and solemn words can not disguise the slack complacency of -LRB- Godard 's -RRB- vision , any more than the gorgeous piano and strings on the soundtrack can drown out the tinny self-righteousness of his voice .",
#  19402: "Were Dylan Thomas alive to witness first-time director Ethan Hawke 's strained Chelsea Walls , he might have been tempted to change his landmark poem to , ` Do Not Go Gentle Into That Good Theatre . '",
#  19448: 'Affirms the gifts of all involved , starting with Spielberg and going right through the ranks of the players -- on-camera and off -- that he brings together .',
#  19480: 'A somewhat disappointing and meandering saga .',
#  19487: "It 's in the action scenes that things fall apart .",
#  19495: "There 's no palpable chemistry between Lopez and male lead Ralph Fiennes , plus the script by Working Girl scribe Kevin Wade is workmanlike in the extreme .",
#  19529: 'A cleverly crafted but ultimately hollow mockumentary .',
#  19538: 'The uneven movie does have its charms and its funny moments but not quite enough of them .',
#  19554: "An unintentionally surreal kid 's picture ... in which actors in bad bear suits enact a sort of inter-species parody of a VH1 Behind the Music episode .",
#  19584: 'It will break your heart many times over .',
#  19591: "This is as lax and limp a comedy as I 've seen in a while , a meander through worn-out material .",
#  19613: "It 's both sitcomishly predictable and cloying in its attempts to be poignant .",
#  19627: "Though this rude and crude film does deliver a few gut-busting laughs , its digs at modern society are all things we 've seen before .",
#  19656: '-LRB- A -RRB- mess .',
#  19658: 'A work that lacks both a purpose and a strong pulse .',
#  19670: 'The sword fighting is well done and Auteuil is a goofy pleasure .',
#  19684: 'a stereotype',
#  19686: 'omitted',
#  19687: 'unsaid',
#  19688: 'The IMAX screen enhances the personal touch of manual animation .',
#  19700: 'Kaufman and Jonze take huge risks to ponder the whole notion of passion -- our desire as human beings for passion in our lives and the emptiness one feels when it is missing .',
#  19739: 'God bless Crudup and his aversion to taking the easy Hollywood road and cashing in on his movie-star gorgeousness .',
#  19763: 'Is it a comedy ?',
#  19766: 'Unlike most surf movies , Blue Crush thrillingly uses modern technology to take the viewer inside the wave .',
#  19786: "The best part about `` Gangs '' was Daniel Day-Lewis .",
#  19799: "Waiting for Godard can be fruitful : ` In Praise of Love ' is the director 's epitaph for himself .",
#  19820: 'An edgy thriller that delivers a surprising punch .',
#  19829: 'The movie would seem less of a trifle if Ms. Sugarman followed through on her defiance of the saccharine .',
#  19848: "` The War of the Roses , ' trailer-trash style .",
#  19860: 'The result is a powerful , naturally dramatic piece of low-budget filmmaking .',
#  19872: 'A fifty car pileup of cliches .',
#  19881: 'Whole stretches of the film may be incomprehensible to moviegoers not already clad in basic black .',
#  19896: '... pitiful , slapdash disaster .',
#  19904: 'Charlotte Sometimes is a brilliant movie .',
#  19910: 'You end up simply admiring this bit or that , this performance or that .',
#  19924: 'Godard has never made a more sheerly beautiful film than this unexpectedly moving meditation on love , history , memory , resistance and artistic transcendence .',
#  19953: "An erotic thriller that 's neither too erotic nor very thrilling , either .",
#  19966: 'Carrying off a spot-on Scottish burr , Duvall -LRB- also a producer -RRB- peels layers from this character that may well not have existed on paper .',
#  19997: 'A solid piece of journalistic work that draws a picture of a man for whom political expedience became a deadly foreign policy .',
#  20022: 'Hopkins , squarely fills the screen .',
#  20029: 'Irwin and his director never come up with an adequate reason why we should pay money for what we can get on television for free .',
#  20055: 'Everything its title implies , a standard-issue crime drama spat out from the Tinseltown assembly line .',
#  20075: 'Unfolds as one of the most politically audacious films of recent decades from any country , but especially from France .',
#  20096: "`` Abandon '' will leave you wanting to abandon the theater .",
#  20108: 'Probably the best case for Christianity since Chesterton and Lewis .',
#  20121: "Before long , you 're desperate for the evening to end .",
#  20132: "It 's all a rather shapeless good time ...",
#  20139: 'Feels more like a rejected X-Files episode than a credible account of a puzzling real-life happening .',
#  20160: 'No amount of good intentions is able to overcome the triviality of the story .',
#  20173: '-LRB- Ramsay -RRB- visually transforms the dreary expanse of dead-end distaste the characters inhabit into a poem of art , music and metaphor .',
#  20200: 'The film has -LRB- its -RRB- moments , but they are few and far between .',
#  20210: "... a sweetly affecting story about four sisters who are coping , in one way or another , with life 's endgame .",
#  20236: "A disturbing examination of what appears to be the definition of a ` bad ' police shooting .",
#  20257: 'Distances you by throwing out so many red herrings , so many false scares , that the genuine ones barely register .',
#  20282: 'Almost .',
#  20283: 'Every sequel you skip will be two hours gained .',
#  20293: 'Been there done that .',
#  20297: "They exist for hushed lines like `` They 're back ! ''",
#  20309: 'Somehow Ms. Griffiths and Mr. Pryce bring off this wild Welsh whimsy .',
#  20325: "The densest distillation of Roberts ' movies ever made .",
#  20337: 'Lots of effort and intelligence are on display but in execution it is all awkward , static , and lifeless rumblings .',
#  20362: 'This is one of the outstanding thrillers of recent years .',
#  20373: 'Consider the film a celluloid litmus test for the intellectual and emotional pedigree of your date and a giant step backward for a director I admire .',
#  20403: 'The subtitled costume drama is set in a remote African empire before cell phones , guns , and the internal combustion engine , but the politics that thump through it are as timely as tomorrow .',
#  20445: 'Opening with some contrived banter , cliches and some loose ends , the screenplay only comes into its own in the second half .',
#  20468: 'A captivating new film .',
#  20473: "If you adored The Full Monty so resoundingly that you 're dying to see the same old thing in a tired old setting , then this should keep you reasonably entertained .",
#  20507: "Worth catching for Griffiths ' warm and winning central performance .",
#  20519: 'Sorvino makes the princess seem smug and cartoonish , and the film only really comes alive when poor Hermocrates and Leontine pathetically compare notes about their budding amours .',
#  20556: "While this has the making of melodrama , the filmmaker cuts against this natural grain , producing a work that 's more interested in asking questions than in answering them .",
#  20590: 'Davis is funny , charming and quirky in her feature film acting debut as Amy .',
#  20605: 'An uncomfortable movie , suffocating and sometimes almost senseless , The Grey Zone does have a center , though a morbid one .',
#  20632: "The lousy John Q all but spits out Denzel Washington 's fine performance in the title role .",
#  20652: 'So devoid of pleasure or sensuality that it can not even be dubbed hedonistic .',
#  20668: "Satin Rouge is not a new , or inventive , journey , but it 's encouraging to see a three-dimensional , average , middle-aged woman 's experience of self-discovery handled with such sensitivity .",
#  20706: 'A pointed , often tender , examination of the pros and cons of unconditional love and familial duties .',
#  20728: "Another trumpet blast that there may be a New Mexican Cinema a-bornin ' . '",
#  20746: 'Gorgeous to look at but insufferably tedious and turgid ... a curiously constricted epic .',
#  20763: "Only about as sexy and dangerous as an actress in a role that reminds at every turn of Elizabeth Berkley 's flopping dolphin-gasm .",
#  20789: "Their contrast is neither dramatic nor comic -- it 's just a weird fizzle .",
#  20803: "Collateral Damage is trash , but it earns extra points by acting as if it were n't .",
#  20823: "When you think you 've figured out Bielinsky 's great game , that 's when you 're in the most trouble : He 's the con , and you 're just the mark .",
#  20858: "Swimming is above all about a young woman 's face , and by casting an actress whose face projects that woman 's doubts and yearnings , it succeeds .",
#  20886: "It 's packed to bursting with incident , and with scores of characters , some fictional , some from history .",
#  20910: "You want to call Domino 's .",
#  20917: "The umpteenth summer skinny dip in Jerry Bruckheimer 's putrid pond of retread action twaddle .",
#  20938: "`` the road paved with good intentions leads to the video store ''",
#  20952: "Chris Columbus ' sequel is faster , livelier and a good deal funnier than his original .",
#  20971: 'Full of flatulence jokes and mild sexual references , Kung Pow !',
#  20984: 'The whole affair is as predictable as can be .',
#  20993: 'The film is a very good viewing alternative for young women .',
#  21002: "To those who have not read the book , the film is a much better mother-daughter tale than last summer 's ` Divine Secrets of the Ya-Ya Sisterhood , ' but that 's not saying much .",
#  21038: 'But it also has many of the things that made the first one charming .',
#  21051: 'Sheridan',
#  21052: "terrified of the book 's irreverent energy , and scotches most",
#  21065: 'humor , bile , and irony',
#  21071: 'This slight premise ... works because of the ideal casting of the masterful British actor Ian Holm as the aged Napoleon .',
#  21097: 'But never mind all that ; the boobs are fantasti',
#  21107: "About Schmidt is Nicholson 's goofy , heartfelt , mesmerizing King Lear .",
#  21120: "It is most of the things Costner movies are known for ; it 's sanctimonious , self-righteous and so eager to earn our love that you want to slap it .",
#  21155: 'This is a very funny , heartwarming film .',
#  21163: "It 's a piece of handiwork that shows its indie tatters and self-conscious seams in places , but has some quietly moving moments and an intelligent subtlety .",
#  21192: "I was amused and entertained by the unfolding of Bielinsky 's cleverly constructed scenario , and greatly impressed by the skill of the actors involved in the enterprise .",
#  21224: 'For most of the distance the picture provides a satisfyingly unsettling ride into the dark places of our national psyche .',
#  21246: 'With very little to add beyond the dark visions already relayed by superb recent predecessors like Swimming With Sharks and The Player , this latest skewering ... may put off insiders and outsiders alike .',
#  21288: "Being unique does n't necessarily equate to being good , no matter how admirably the filmmakers have gone for broke .",
#  21309: 'The respective charms of Sandra Bullock and Hugh Grant have worn threadbare .',
#  21328: "Like the Hanks character , he 's a slow study : The action is stilted and the tabloid energy embalmed .",
#  21351: '... enthusiastically invokes the percussion rhythm , the brass soul and the sense of fierce competition that helps make great marching bands half the fun of college football games .',
#  21390: "What 's invigorating about it is that it does n't give a damn .",
#  21403: 'Cacoyannis is perhaps too effective in creating an atmosphere of dust-caked stagnation and labored gentility .',
#  21422: 'An entertaining , if ultimately minor , thriller .',
#  21430: "The real star of this movie is the score , as in the songs translate well to film , and it 's really well directed .",
#  21457: 'Punitively affirmational parable .',
#  21462: 'Demme finally succeeds in diminishing his stature from Oscar-winning master to lowly studio hack .',
#  21481: 'Horrid little propaganda film with fascinating connections not only to the Serbs themselves but also to a network of American right-wing extremists .',
#  21508: "Star\\/producer Salma Hayek and director Julie Taymor have infused Frida with a visual style unique and inherent to the titular character 's paintings and in the process created a masterful work of art of their own .",
#  21550: 'This one is not nearly as dreadful as expected .',
#  21557: "But ... in trying to capture the novel 's deeper intimate resonances , the film has -- ironically - distanced us from the characters .",
#  21582: 'Real Women Have Curves wears its empowerment on its sleeve but even its worst harangues are easy to swallow thanks to remarkable performances by Ferrera and Ontiveros .',
#  21615: "There 's a whole heap of nothing at the core of this slight coming-of-age\\/coming-out tale .",
#  21632: 'A sensitive , moving , brilliantly constructed work .',
#  21641: "It pulls the rug out from under you , just when you 're ready to hate one character , or really sympathize with another character , something happens to send you off in different direction .",
#  ...}

# %%
df_filtered = df.iloc[list(unique_phrase_dic.keys())]

# %%
#dataframe filtered to carry only unique values
df_filtered.phrase[63]
# Out:
# 'This quiet , introspective and entertaining independent is worth seeking .'

# %%
# Getting rid of white space existing before commas, periods, apostrophes.
# Correctly writing "doesn't" and "don't"


# df_filtered.phrase = df_filtered.phrase.apply(lambda x: re.sub(r'\s([?.!,''"](?:\s|$))', r'\1', x))
df_filtered.phrase = df_filtered.phrase.apply(lambda x: re.sub(r"\b\s+'\b", r"'", x))
df_filtered.phrase = df_filtered.phrase.str.replace("does n't", "doesn't")
df_filtered.phrase = df_filtered.phrase.str.replace("do n't", "don't")
# Out:
# /Users/Haebichan/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:4401: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
# Sentiment value 2 has drastically gone down after filtering 

hist(df_filtered.sentiment, bins = 5, alpha = 0.5);
xticks = range(5);
print(df_filtered.sentiment.value_counts(1));
# Out:
# 3    0.270329
# 1    0.257084
# 2    0.200530
# 4    0.148238
# 0    0.123819
# Name: sentiment, dtype: float64

# %% [markdown]
# # Baseline Machine Learning Model

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.linear_model import SGDClassifier, LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.metrics import confusion_matrix, accuracy_score, roc_auc_score

from nltk.stem import WordNetLemmatizer, PorterStemmer

# %%
# lemmatizer = WordNetLemmatizer()
# w_tokenizer = nltk.tokenize.WhitespaceTokenizer()


# def lemmatize_text(text):
#     return [lemmatizer.lemmatize(w) for w in w_tokenizer.tokenize(text)]

# df_filtered['text_lemmatized'] = df_filtered.phrase.apply(df_filtered.phrase)

# %%
# vectorizers = [CountVectorizer(stop_words = 'english'), TfidfVectorizer(stop_words = 'english')]

# for vectorizer in vectorizers:
    
#     features = vectorizer.fit_transform(df_filtered.phrase).toarray()
#     labels = df_filtered.sentiment

#     models = []
#     models.append(('LR',LogisticRegression()))
#     models.append(('mnb', MultinomialNB()))
#     models.append(('RF', RandomForestClassifier()))

#     results = [] 
#     names = []

#     for name, model in models:
#         kfold =KFold(n_splits = 10)
#         cv_results = cross_val_score(model, features, labels, scoring = 'accuracy')
#         results.append(cv_results)
#         names.append(name)
#         msg = "{} -{}: {}".format(vectorizer.__class__.__name__, name, cv_results.mean())
#         print(msg)
    
#     print('_______________________________')

# %% [markdown]
# # Sentiment Analysis with Vader

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from textblob import TextBlob
analyzer = SentimentIntensityAnalyzer()

# %%
snt = analyzer.polarity_scores(df_filtered.phrase[0])

# %%
print(df_filtered.phrase[0], snt)
# Out:
# A series of escapades demonstrating the adage that what is good for the goose is also good for the gander , some of which occasionally amuses but none of which amounts to much of a story . {'neg': 0.0, 'neu': 0.843, 'pos': 0.157, 'compound': 0.5579}

# %%
ex = analyzer.polarity_scores('This is a love story')
ex2 = analyzer.polarity_scores('I love this story')

# %%
print(ex, ex2)
# Out:
# {'neg': 0.0, 'neu': 0.417, 'pos': 0.583, 'compound': 0.6369} {'neg': 0.0, 'neu': 0.323, 'pos': 0.677, 'compound': 0.6369}

# %%
df_filtered
# Out:
#         phraseid  sentenceid  \
# 0              1           1
# 63            64           2
# 81            82           3
# 116          117           4
# 156          157           5
# 166          167           6
# 198          199           7
# 213          214           8
# 247          248           9
# 259          260          10
# 271          272          11
# 306          307          12
# 352          353          13
# 363          364          14
# 407          408          15
# 423          424          16
# 458          459          17
# 473          474          18
# 516          517          19
# 536          537          20
# 551          552          21
# 563          564          22
# 619          620          23
# 647          648          24
# 686          687          25
# 702          703          26
# 725          726          27
# 741          742          28
# 786          787          29
# 810          811          30
# ...          ...         ...
# 155556    155557        8514
# 155570    155571        8515
# 155593    155594        8516
# 155612    155613        8517
# 155632    155633        8518
# 155645    155646        8519
# 155666    155667        8520
# 155693    155694        8521
# 155699    155700        8522
# 155703    155704        8523
# 155721    155722        8524
# 155733    155734        8525
# 155764    155765        8526
# 155780    155781        8527
# 155802    155803        8528
# 155818    155819        8529
# 155836    155837        8531
# 155849    155850        8532
# 155876    155877        8533
# 155900    155901        8534
# 155911    155912        8535
# 155914    155915        8536
# 155930    155931        8537
# 155949    155950        8538
# 155963    155964        8539
# 155984    155985        8540
# 155997    155998        8541
# 156021    156022        8542
# 156031    156032        8543
# 156039    156040        8544
#
#                                                    phrase  sentiment  \
# 0       A series of escapades demonstrating the adage ...          1
# 63      This quiet , introspective and entertaining in...          4
# 81      Even fans of Ismail Merchant's work , I suspec...          1
# 116     A positively thrilling combination of ethnogra...          3
# 156     Aggressive self-glorification and a manipulati...          1
# 166     A comedy-drama of nearly epic proportions root...          4
# 198     Narratively , Trouble Every Day is a plodding ...          1
# 213     The Importance of Being Earnest , so thick wit...          3
# 247                  But it doesn't leave you with much .          1
# 259               You could hate it for the same reason .          1
# 271     There's little to recommend Snow Dogs , unless...          1
# 306     Kung Pow is Oedekerk's realization of his chil...          1
# 352                The performances are an absolute joy .          4
# 363     Fresnadillo has something serious to say about...          3
# 407     I still like Moonlight Mile , better judgment ...          3
# 423     A welcome relief from baseball movies that try...          3
# 458     a bilingual charmer , just like the woman who ...          3
# 473     Like a less dizzily gorgeous companion to Mr. ...          2
# 516     As inept as big-screen remakes of The Avengers...          1
# 536     It's everything you'd expect -- but nothing mo...          2
# 551                     Best indie of the year , so far .          4
# 563     Hatfield and Hicks make the oddest of couples ...          3
# 619     It's like going to a house party and watching ...          1
# 647     That the Chuck Norris `` grenade gag '' occurs...          2
# 686     The plot is romantic comedy boilerplate from s...          2
# 702     It arrives with an impeccable pedigree , mongr...          2
# 725     A film that clearly means to preach exclusivel...          2
# 741     While The Importance of Being Earnest offers o...          1
# 786     The latest vapid actor's exercise to appropria...          1
# 810     More vaudeville show than well-constructed nar...          2
# ...                                                   ...        ...
# 155556  Every conceivable mistake a director could mak...          0
# 155570  It's the kind of movie that , aside from Rober...          4
# 155593  Williams creates a stunning , Taxi Driver-esqu...          4
# 155612  Campbell Scott finds the ideal outlet for his ...          3
# 155632  Has a certain ghoulish fascination , and gener...          3
# 155645  With its parade of almost perpetually wasted c...          1
# 155666  Bolstered by an astonishing voice cast -LRB- e...          3
# 155693                A witty , whimsical feature debut .          3
# 155699                     Exhilarating , funny and fun .          4
# 155703  As an entertainment destination for the genera...          1
# 155721  Downbeat , period-perfect biopic hammers home ...          3
# 155733  None of this so-called satire has any sting to...          1
# 155764  The Santa Clause 2 is a barely adequate babysi...          2
# 155780  Sometimes there are very , very good reasons f...          1
# 155802  It makes you believe the cast and crew thoroug...          3
# 155818  The underworld urban angst is derivative of Ma...          3
# 155836  Even if you have no interest in the gang-infes...          2
# 155849  The film doesn't really care about the thousan...          1
# 155876  Proves a servicable World War II drama that ca...          3
# 155900  This movie ... doesn't deserve the energy it t...          1
# 155911                                In this case zero .          1
# 155914  Simply put , there should have been a more com...          1
# 155930  Definitely in the guilty pleasure B-movie cate...          3
# 155949  It's an experience in understanding a unique c...          3
# 155963  The French director has turned out nearly 21\/...          0
# 155984  ... either you're willing to go with this clau...          2
# 155997  Despite these annoyances , the capable Claybur...          2
# 156021  -LRB- Tries -RRB- to parody a genre that's alr...          1
# 156031  The movie's downfall is to substitute plot for...          1
# 156039  The film is darkly atmospheric , with Herrmann...          2
#
#         review_word_length
# 0                       37
# 63                      11
# 81                      21
# 116                     26
# 156                      7
# 166                     19
# 198                     10
# 213                     20
# 247                      9
# 259                      9
# 271                     22
# 306                     30
# 352                      7
# 363                     27
# 407                     11
# 423                     26
# 458                     11
# 473                     27
# 516                     14
# 536                     11
# 551                      9
# 563                     41
# 619                     19
# 647                     25
# 686                     11
# 702                     16
# 725                     12
# 741                     36
# 786                     16
# 810                     19
# ...                    ...
# 155556                  15
# 155570                  32
# 155593                  18
# 155612                  17
# 155632                  15
# 155645                  22
# 155666                  32
# 155693                   7
# 155699                   6
# 155703                  18
# 155721                  11
# 155733                  33
# 155764                  23
# 155780                  25
# 155802                  18
# 155818                  22
# 155836                  12
# 155849                  32
# 155876                  30
# 155900                  17
# 155911                   5
# 155914                  19
# 155930                  21
# 155949                  16
# 155963                  29
# 155984                  16
# 155997                  26
# 156021                  17
# 156031                  11
# 156039                  21
#
# [8682 rows x 5 columns]

# %% [markdown]
# #### Adding sentiment analysis with respective phrases that are vectorized. Training ML models with the merged values

# %%
polarity_dic = {}

for sentence in df_filtered.phrase:
    vader_sentiment = analyzer.polarity_scores(sentence).items()
    sent_list = []
    for sentiment in vader_sentiment:
        sent_list.append(sentiment[1])
        
    polarity_dic[sentence] = sent_list

# %%
polarity_df = pd.DataFrame(list(polarity_dic.values()), df_filtered.reset_index()['index']).rename(columns = {0:'neg', 1:'neu',2:'pos', 3:'compound'})

# %%
df_filtered_polarity = df_filtered.join(polarity_df)

# %% [markdown]
# #### Results only slightly better. Also, removing stopwords worsens the performance

# %%
# vectorizers = [CountVectorizer(), TfidfVectorizer(
#     sublinear_tf=True,
#     strip_accents='unicode',
#     analyzer='word',
#     token_pattern=r'\w{1,}',
#     stop_words='english',
#     ngram_range=(1, 3),
#     max_features=18000)]

# for vectorizer in vectorizers:
    
#     features = vectorizer.fit_transform(df_filtered_polarity.phrase).toarray()
#     features_added = pd.DataFrame(features).join(df_filtered_polarity.reset_index()['neg, neu, pos, compound'.split(', ')])
#     labels = df_filtered.sentiment

#     models = []
#     models.append(('LR',LogisticRegression()))
# #     models.append(('mnb', MultinomialNB()))
#     models.append(('RF', RandomForestClassifier()))

#     results = []
#     names = []

#     for name, model in models:
#         kfold =KFold(n_splits = 10)
#         cv_results = cross_val_score(model, features_added, labels, scoring = 'accuracy')
#         results.append(cv_results)
#         names.append(name)
#         msg = "{} -{}: {}".format(vectorizer.__class__.__name__, name, cv_results.mean())
#         print(msg)
    
#     print('_______________________________')

# %%
# vectorizers = [CountVectorizer(), TfidfVectorizer(
#     sublinear_tf=True,
#     strip_accents='unicode',
#     analyzer='word',
#     token_pattern=r'\w{1,}',
#     ngram_range=(1, 3),
#     max_features=18000)]

# for vectorizer in vectorizers:
    
#     features = vectorizer.fit_transform(df_filtered_polarity.phrase).toarray()
#     features_added = pd.DataFrame(features).join(df_filtered_polarity.reset_index()['neg, neu, pos, compound'.split(', ')])
#     labels = df_filtered.sentiment

#     models = []
#     models.append(('LR',LogisticRegression()))
# #     models.append(('mnb', MultinomialNB()))
#     models.append(('RF', RandomForestClassifier()))

#     results = []
#     names = []

#     for name, model in models:
#         kfold =KFold(n_splits = 10)
#         cv_results = cross_val_score(model, features_added, labels, scoring = 'accuracy')
#         results.append(cv_results)
#         names.append(name)
#         msg = "{} -{}: {}".format(vectorizer.__class__.__name__, name, cv_results.mean())
#         print(msg)
    
#     print('_______________________________')

# %%
# from nltk import word_tokenize, pos_tag, ne_chunk
# from nltk.tag import StanfordNERTagger

# st = StanfordNERTagger('/usr/share/stanford-ner/classifiers/english.all.3class.distsim.crf.ser.gz','/usr/share/stanford-ner/stanford-ner.jar', encoding='utf-8')

# tagged = pos_tag(df_filtered.phrase[407].split())

# ne_chunk(tagged, binary = True)

# %% [markdown]
# # Filtering Named Entity Recognition / Proper Nouns

# %%
from nltk import ngrams
from nltk.tokenize import RegexpTokenizer
from collections import Counter
import re

# %%
sentence = df_filtered.phrase[198]

tagged_sent = pos_tag(sentence.split())
print(tagged_sent)


propernouns = [word for word,pos in tagged_sent if pos == 'NNP']
# Out:
# [('Narratively', 'RB'), (',', ','), ('Trouble', 'JJ'), ('Every', 'DT'), ('Day', 'NNP'), ('is', 'VBZ'), ('a', 'DT'), ('plodding', 'VBG'), ('mess', 'NN'), ('.', '.')]

# %%
# for i in df_filtered.index:
#     sentence = df_filtered.phrase[i].replace("'s","'S").split()
#     for index, word in enumerate(sentence):
#         prev_index = index - 1
#         next_index = index + 1

#         if sentence[index].islower():
#             if sentence[prev_index].istitle() and sentence[next_index].istitle() and next_index < len(sentence) -1:  
#                 sentence[index] = sentence[index].title()

# %%
sentence = df_filtered.phrase[198].split()

NamedEnt = []

for index, word in enumerate(sentence):
    next_index = index + 1
    if word.istitle():
        if sentence[next_index].istitle():
            if sentence[index] not in NamedEnt:
                NamedEnt.append(sentence[index])
            if sentence[next_index] not in NamedEnt:
                NamedEnt.append(sentence[next_index])

# %%
df_filtered.phrase[213]
# Out:
# "The Importance of Being Earnest , so thick with wit it plays like a reading from Bartlett's Familiar Quotations"

# %%
sentence = df_filtered.phrase[213].replace("'s","'S").split()

for index, word in enumerate(sentence):
    prev_index = index - 1
    next_index = index + 1
    
    if sentence[index].islower():
        if sentence[prev_index].istitle() and sentence[next_index].istitle():
            sentence[index] = sentence[index].title() 
            

print(sentence)            
            
NamedEnt2 = [] 
for index, word in enumerate(sentence):
    next_index = index + 1
    if word.istitle():
        if index < len(sentence) -1:
            if sentence[next_index].istitle():
                if sentence[index] not in NamedEnt2:
                    NamedEnt2.append(sentence[index])
                if sentence[next_index] not in NamedEnt2:
                    NamedEnt2.append(sentence[next_index])
# Out:
# ['The', 'Importance', 'Of', 'Being', 'Earnest', ',', 'so', 'thick', 'with', 'wit', 'it', 'plays', 'like', 'a', 'reading', 'from', "Bartlett'S", 'Familiar', 'Quotations']

# %%
NamedEnt2
# Out:
# ['The',
#  'Importance',
#  'Of',
#  'Being',
#  'Earnest',
#  "Bartlett'S",
#  'Familiar',
#  'Quotations']

# %%
# sent = []
# for i in sentence:
#     if i in NamedEnt2:
#         i = 'NamedEntity'
#         sent.append(i)
#     else:
#         sent.append(i)

# %%
sent2 = []

i = 0
while i < len(sentence):
    if sentence[i] in NamedEnt2:  
        while i < len(sentence) and sentence[i] in NamedEnt2:
            i += 1
        sent2.append('NamedEntity')
    else:
        sent2.append(sentence[i])
        i += 1

# %%
sent2
# Out:
# ['NamedEntity',
#  ',',
#  'so',
#  'thick',
#  'with',
#  'wit',
#  'it',
#  'plays',
#  'like',
#  'a',
#  'reading',
#  'from',
#  'NamedEntity']

# %%
"Bartlett's".title()

# %%
df_filtered.phrase[213].replace("'s","'S")

# %%
sentiment_4_text = ' '.join(df_filtered[df_filtered.sentiment == 4]['phrase'].values)

# %%
bigrams = ngrams(sentiment_4_text.split(), 2)
trigrams = ngrams(sentiment_4_text.split(), 3)
fourgrams = ngrams(sentiment_4_text.split(), 4)
fivegrams = ngrams(sentiment_4_text.split(), 5)

# %%
#Trigrams demonstrate that stopwords carry strong signal

Counter(fourgrams).most_common(10)
# Out:
# [(('one', 'of', 'the', 'best'), 8),
#  (('is', 'one', 'of', 'the'), 8),
#  (('one', 'of', 'the', 'most'), 7),
#  (('One', 'of', 'the', 'most'), 6),
#  (('One', 'of', 'the', 'best'), 6),
#  (('one', 'of', 'the', "year's"), 5),
#  (('of', 'the', "year's", 'most'), 3),
#  (('the', 'best', 'films', 'of'), 3),
#  (('best', 'films', 'of', 'the'), 3),
#  (('films', 'of', 'the', 'year.'), 3)]

# %%
fourgram_list = []

for i in range(5):
    sentiment = ' '.join(df_filtered[df_filtered.sentiment == i]['phrase'].values)
    fourgram = ngrams(sentiment.split(), 4)
    most_common_fourgrams = Counter(fourgram).most_common(10)
    fourgram_list.append([list(i[0]) for i in most_common_fourgrams])

# %%
for i in fourgram_list:
    for j in i:
        print(' '.join(j))
# Out:
# It's hard to imagine
# one of the worst
# One of the most
# I'm not sure which
# the worst kind of
# as if it were
# This is the kind
# is the kind of
# the kind of movie
# the fact that the
# it wants to be
# is the kind of
# the kind of movie
# Queen of the Damned
# to the level of
# whether it wants to
# wants to be a
# like the work of
# were it not for
# The script is a
# is one of those
# much as it is
# from start to finish.
# It may not be
# in a film that
# you might want to
# but neither is it
# in the right place
# one of the most
# movie equivalent of a
# as one of the
# one of the most
# but it is a
# My Big Fat Greek
# The Lady and the
# Lady and the Duke
# the film is a
# in the face of
# Real Women Have Curves
# Big Fat Greek Wedding
# one of the best
# is one of the
# one of the most
# One of the most
# One of the best
# one of the year's
# of the year's most
# the best films of
# best films of the
# films of the year.

# %%
lemma  = WordNetLemmatizer()
porter = PorterStemmer()

def stem_sentences(sentence):
    tokens = sentence.split()
    stemmed_tokens = [lemma.lemmatize(token) for token in tokens]
    return ' '.join(stemmed_tokens)

df_filtered_polarity['phrase_lemmatized'] = df_filtered_polarity.phrase.apply(stem_sentences)

# %%
# for i in range(5):
#     sentiment_text = ''.join(df_filtered[df_filtered.sentiment == i]['phrase'].values)

#     tokenizer = RegexpTokenizer(r'\w+')

#     sentiment_text_filtered = ' '.join(tokenizer.tokenize(sentiment_text))

#     trigrams = ngrams(sentiment_4_text_filtered.split(), 3)

# %% [markdown]
# # Character vectorizer

# %%
x_train, x_test, y_train, y_test = train_test_split(df_filtered.phrase, df_filtered.sentiment, test_size = 0.3)

# %%
word_vectorizer = TfidfVectorizer(
    sublinear_tf=True,
    strip_accents='unicode',
    analyzer='word',
    token_pattern=r'\w{1,}',
    ngram_range=(1, 3),
    max_features=18000)
word_vectorizer.fit(df_filtered.phrase)
train_word_features = word_vectorizer.transform(x_train)
test_word_features = word_vectorizer.transform(x_test)

# %%
char_vectorizer = TfidfVectorizer(
    sublinear_tf=True,
    strip_accents='unicode',
    analyzer='char',
    ngram_range=(1, 7),
    max_features=60000)
char_vectorizer.fit(df_filtered.phrase)
train_char_features = char_vectorizer.transform(x_train)
test_char_features = char_vectorizer.transform(x_test)

# %%
train_features = hstack((train_char_features.toarray(), train_word_features.toarray()))
test_features = hstack((test_char_features, test_word_features))

# %%
Sentiments = pd.get_dummies(train.Sentiment, drop_first = True)

# %%
Sentiments.iloc[:,0].values
# Out:
# array([1, 0, 0, ..., 0, 0, 0], dtype=uint8)

# %%
# predictions_chars = []

# submission_chars = pd.DataFrame.from_dict({'phraseid': test['PhraseId']})

# for i in range(4):
#     train_target = Sentiments.iloc[:,i].values
# #     train_target = Sentiments[i].values
#     classifier = LogisticRegression(C=2.6, solver='sag')
#     classifier.fit(train_features, train_target)
#     submission_chars[str(i)] = classifier.predict_proba(test_char_features)[:, 1]

# %% [markdown]
# # Filtering

# %%
# tagged=nltk.pos_tag(words)

# namedEnt=nltk.ne_chunk(tagged)

phrase = df_filtered.phrase[81]
words = word_tokenize(phrase)
tagged = nltk.pos_tag(words)

# %%
[i for i in tagged if i[1] == 'NN' or i[1] == 'NNS' or i[1] == 'VBZ' or i [1] == 'ADJP' or i[1] == 'JJ' or i[1] == 'VBG']
# Out:
# [('fans', 'NNS'),
#  ('work', 'NN'),
#  ('hard', 'JJ'),
#  ('time', 'NN'),
#  ('sitting', 'VBG')]

# %%
def cleanse():
    k = []
    
    for i in df_filtered.index:
        phrase = df_filtered.phrase[0]
        words = word_tokenize(phrase)
        tagged = nltk.pos_tag(words)
        remaining_tuple = [i for i in tagged if i[1] == 'NN' or i[1] == 'NNS' or i[1] == 'VBZ' or i [1] == 'ADJP' or i[1] == 'JJ' or i[1] == 'VBG']
        remaining_words = [i[0] for i in remaining_tuple]
        join_words = ' '.join(remaining_words)
        k.append(join_words)
        df_pos_tag = pd.DataFrame(np.array(l))
        return df_pos_tag

# %%
# df_filtered.phrase.apply(cleanse())

# %%
l = []

for i in df_filtered.index:
    phrase = df_filtered.phrase[i]
    words = word_tokenize(phrase)
    tagged = nltk.pos_tag(words)
    remaining_tuple = [i for i in tagged if i[1] == 'NN' or i[1] == 'NNS' or i[1] == 'VBZ' or i [1] == 'ADJP' or i[1] == 'JJ' or i[1] == 'VBG']
    remaining_words = [i[0] for i in remaining_tuple]
    join_words = ' '.join(remaining_words)
    k.append(join_words)
    df_pos_tag = pd.DataFrame(np.array(l))

# %%
df_pos_tag
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-2a9d3793977c> in <module>()
# ----> 1 df_pos_tag
#
# NameError: name 'df_pos_tag' is not defined

# %%
pd.DataFrame(np.array(k))
# Out:
#                                                       0
# 0     series escapades demonstrating adage is good g...
# 1     quiet introspective entertaining independent i...
# 2                           fans work hard time sitting
# 3     thrilling combination ethnography intrigue bet...
# 4     Aggressive self-glorification manipulative whi...
# 5     comedy-drama epic proportions sincere performa...
# 6                              Trouble is plodding mess
# 7         Importance thick wit plays reading Quotations
# 8                                             does much
# 9                                           same reason
# 10    's little considers dialogue perverse escapism...
# 11    is realization childhood dream martial-arts fl...
# 12                            performances absolute joy
# 13    has something serious ways extravagant chance ...
# 14                                             judgment
# 15    welcome relief baseball movies hard mythic is ...
# 16                              bilingual charmer woman
# 17            gorgeous companion movie mainland setting
# 18                             inept big-screen remakes
# 19                                's everything nothing
# 20                                           indie year
# 21    couples sense movie becomes study gambles publ...
# 22    's going house party watching host frothing ex...
# 23    gag occurs times is good indication serious-mi...
# 24            plot is romantic comedy boilerplate start
# 25    arrives impeccable pedigree mongrel pep indeci...
# 26                                           film means
# 27    offers opportunities occasional smiles chuckle...
# 28                       vapid actor exercise structure
# 29    vaudeville well-constructed narrative terms 's...
# ...                                                 ...
# 8652     conceivable mistake director filming opera has
# 8653               's kind movie few others moviemakers
# 8654  creates stunning portrayal man teetering edge ...
# 8655        finds ideal outlet flick-knife diction role
# 8656  Has certain ghoulish fascination generates fai...
# 8657     parade wasted characters feels hazy high takes
# 8658  astonishing voice -LRB- excepting interesting ...
# 8659                      witty whimsical feature debut
# 8660                             Exhilarating funny fun
# 8661  entertainment destination general public sets ...
# 8662  period-perfect biopic hammers heavy-handed mor...
# 8663  None so-called satire has sting is afraid biti...
# 8664                        is adequate babysitter kids
# 8665       good reasons certain movies jar remote shelf
# 8666                  makes cast crew small-budget film
# 8667   underworld urban angst is derivative film speaks
# 8668                             interest gang-infested
# 8669  film does thousands cares Ryan meets future wi...
# 8670  Proves servicable drama contrivances calls att...
# 8671                     movie does energy takes bad is
# 8672                                          case zero
# 8673                                  compelling excuse
# 8674     guilty pleasure category is inane is enjoyable
# 8675  's experience understanding unique culture is ...
# 8676  French director has hours unfocused tedious ci...
# 8677                     willing claustrophobic concept
# 8678  annoyances capable great job anchoring charact...
# 8679                                -LRB- genre 's joke
# 8680                 movie downfall is plot personality
# 8681  film is darkly atmospheric suggesting sadness ...
#
# [8682 rows x 1 columns]

# %% [markdown]
# # Keras

# %%
from nltk import FreqDist
entire_text = ' '.join(df_filtered.phrase.values)

remove = ".,"
table = str.maketrans("","",remove)
entire_text_filtered = entire_text.translate(table)
entire_text_filtered

all_words = word_tokenize(entire_text_filtered)

dist = FreqDist(all_words)

# %%
max_features = len(dist)
batch_size = 128
epochs = 3
num_classes=5

# %%
from keras.preprocessing import sequence,text
from keras.preprocessing.text import Tokenizer
from keras.models import Sequential
from keras.layers import Dense,Dropout,Embedding,LSTM,Conv1D,GlobalMaxPooling1D,Flatten,MaxPooling1D,GRU,SpatialDropout1D,Bidirectional
from keras.callbacks import EarlyStopping
from keras.utils import to_categorical
from keras.losses import categorical_crossentropy
from keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,f1_score

# %%
model=Sequential()

model.add(Embedding(max_features,100,mask_zero=True))
model.add(LSTM(64,dropout=0.4, recurrent_dropout=0.4,return_sequences=True))
model.add(LSTM(32,dropout=0.5, recurrent_dropout=0.5,return_sequences=False))
model.add(Dense(num_classes,activation='softmax'))
model.compile(loss='categorical_crossentropy',optimizer=Adam(lr=0.001),metrics=['accuracy'])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_4 (Embedding)      (None, None, 100)         1819200
# _________________________________________________________________
# lstm_21 (LSTM)               (None, None, 64)          42240
# _________________________________________________________________
# lstm_22 (LSTM)               (None, 32)                12416
# _________________________________________________________________
# dense_9 (Dense)              (None, 5)                 165
# =================================================================
# Total params: 1,874,021
# Trainable params: 1,874,021
# Non-trainable params: 0
# _________________________________________________________________

# %%
features = vectorizer.fit_transform(df_filtered_polarity.phrase).toarray()
features_added = pd.DataFrame(features).join(df_filtered_polarity.reset_index()['neg, neu, pos, compound'.split(', ')])
labels = df_filtered.sentiment

# %%
x_train, x_test, y_train, y_test = train_test_split(features_added, pd.get_dummies(labels), test_size = 0.3)

# %%
model.fit(x_train, y_train,epochs=epochs, batch_size=batch_size,verbose=1)
# Out:
# Epoch 1/3

# %%
labels.shape
# Out:
# (8682,)

# %%
pd.get_dummies(labels)
# Out:
#         0  1  2  3  4
# 0       0  1  0  0  0
# 63      0  0  0  0  1
# 81      0  1  0  0  0
# 116     0  0  0  1  0
# 156     0  1  0  0  0
# 166     0  0  0  0  1
# 198     0  1  0  0  0
# 213     0  0  0  1  0
# 247     0  1  0  0  0
# 259     0  1  0  0  0
# 271     0  1  0  0  0
# 306     0  1  0  0  0
# 352     0  0  0  0  1
# 363     0  0  0  1  0
# 407     0  0  0  1  0
# 423     0  0  0  1  0
# 458     0  0  0  1  0
# 473     0  0  1  0  0
# 516     0  1  0  0  0
# 536     0  0  1  0  0
# 551     0  0  0  0  1
# 563     0  0  0  1  0
# 619     0  1  0  0  0
# 647     0  0  1  0  0
# 686     0  0  1  0  0
# 702     0  0  1  0  0
# 725     0  0  1  0  0
# 741     0  1  0  0  0
# 786     0  1  0  0  0
# 810     0  0  1  0  0
# ...    .. .. .. .. ..
# 155556  1  0  0  0  0
# 155570  0  0  0  0  1
# 155593  0  0  0  0  1
# 155612  0  0  0  1  0
# 155632  0  0  0  1  0
# 155645  0  1  0  0  0
# 155666  0  0  0  1  0
# 155693  0  0  0  1  0
# 155699  0  0  0  0  1
# 155703  0  1  0  0  0
# 155721  0  0  0  1  0
# 155733  0  1  0  0  0
# 155764  0  0  1  0  0
# 155780  0  1  0  0  0
# 155802  0  0  0  1  0
# 155818  0  0  0  1  0
# 155836  0  0  1  0  0
# 155849  0  1  0  0  0
# 155876  0  0  0  1  0
# 155900  0  1  0  0  0
# 155911  0  1  0  0  0
# 155914  0  1  0  0  0
# 155930  0  0  0  1  0
# 155949  0  0  0  1  0
# 155963  1  0  0  0  0
# 155984  0  0  1  0  0
# 155997  0  0  1  0  0
# 156021  0  1  0  0  0
# 156031  0  1  0  0  0
# 156039  0  0  1  0  0
#
# [8682 rows x 5 columns]
